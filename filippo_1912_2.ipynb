# %% [markdown]
# # Import libraries

# %%
# Fix randomness and hide warnings
seed = 42

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd()+'/configs/'

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

import random
random.seed(seed)

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
print(tf.__version__)
# Out:
# 2.14.0

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', size=16)
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Load and process data

# %%
# Load the data from the files
training_data = np.load('training/processed_data.npy')
valid_periods = np.load('training/valid_periods.npy')
categories = np.load('training/categories.npy')

training_data.shape, valid_periods.shape, categories.shape
# Out:
# ((48000, 2776), (48000, 2), (48000,))

# %%
# Convert training_data and categories to DataFrame
data_df = pd.DataFrame(training_data, columns=[f'Timestep_{i+1}' for i in range(training_data.shape[1])])
categories_df = pd.DataFrame(categories, columns=['Category'])

# Concatenate DataFrames along the columns
df = pd.concat([data_df, categories_df], axis=1)

# Display the resulting DataFrame
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48000 entries, 0 to 47999
# Columns: 2777 entries, Timestep_1 to Category
# dtypes: float64(2776), object(1)
# memory usage: 1017.0+ MB
#          Timestep_1    Timestep_2    Timestep_3    Timestep_4    Timestep_5  \
# count  48000.000000  48000.000000  48000.000000  48000.000000  48000.000000
# mean       0.294617      0.296570      0.311277      0.312676      0.315905
# std        0.313868      0.309717      0.316246      0.316806      0.308752
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.017053      0.026143      0.036552      0.041840      0.048021
# 50%        0.164482      0.166667      0.179424      0.177778      0.189224
# 75%        0.530799      0.531936      0.558958      0.557046      0.563917
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#          Timestep_6    Timestep_7    Timestep_8    Timestep_9   Timestep_10  \
# count  48000.000000  48000.000000  48000.000000  48000.000000  48000.000000
# mean       0.327528      0.324596      0.323519      0.326198      0.324225
# std        0.312038      0.312138      0.310601      0.308453      0.306235
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.054732      0.053503      0.053497      0.059964      0.062067
# 50%        0.204628      0.198634      0.199197      0.202721      0.200518
# 75%        0.585731      0.580660      0.577783      0.579325      0.570832
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#        ...  Timestep_2767  Timestep_2768  Timestep_2769  Timestep_2770  \
# count  ...   48000.000000   48000.000000   48000.000000   48000.000000
# mean   ...       0.000005       0.000005       0.000005       0.000005
# std    ...       0.001105       0.001194       0.001158       0.001136
# min    ...       0.000000       0.000000       0.000000       0.000000
# 25%    ...       0.000000       0.000000       0.000000       0.000000
# 50%    ...       0.000000       0.000000       0.000000       0.000000
# 75%    ...       0.000000       0.000000       0.000000       0.000000
# max    ...       0.242176       0.261673       0.253678       0.248855
#
#        Timestep_2771  Timestep_2772  Timestep_2773  Timestep_2774  \
# count   48000.000000   48000.000000   48000.000000   48000.000000
# mean        0.000005       0.000005       0.000006       0.000006
# std         0.001151       0.001191       0.001223       0.001242
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         0.252103       0.260920       0.267974       0.272139
#
#        Timestep_2775  Timestep_2776
# count   48000.000000   48000.000000
# mean        0.000006       0.000005
# std         0.001232       0.001197
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         0.000000       0.000000
# 75%         0.000000       0.000000
# max         0.269904       0.262239
#
# [8 rows x 2776 columns]

# %%
# Inspect activities timestamps
plt.figure(figsize=(17,5))
sns.countplot(x = 'Category', data = df, order = sorted(df['Category'].unique()))
plt.title('Activity Timestamps')
plt.show()

# %%
# Plot some samples
for category in "ABCDEF":
    to_be_inspected = 4

    plt.figure(figsize=(17, 3))  # Adjust the figure size as needed
    plt.suptitle(f'Category {category} - Time Series Samples')

    for idx in range(len(training_data)):
        if to_be_inspected == 0:
            break

        if categories[idx] != category:
            continue

        plt.subplot(1, 5, 6 - to_be_inspected)  # 1 row, 5 columns, and the current plot position
        plt.plot(training_data[idx])
        plt.title(f'Sample {idx + 1}')
        plt.xlabel('Time Steps')
        plt.ylabel('Feature Value')

        to_be_inspected -= 1

    plt.tight_layout()  # Adjust layout for better appearance
    plt.show()

# %% [markdown]
# ## Split, Encode and Normalize

# %%
features = df.drop('Category', axis=1)
target = df['Category']

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, stratify=target, random_state=42)

# Display the shapes of the resulting sets
print("Training set shape:", X_train.shape, y_train.shape)
print("Testing set shape:", X_test.shape, y_test.shape)
# Out:
# Training set shape: (38400, 2776) (38400,)
# Testing set shape: (9600, 2776) (9600,)

# %%
# Plot for training set
plt.figure(figsize=(17, 5))
plt.subplot(1, 2, 1)  # 1 row, 2 columns, and the first plot
sns.countplot(x=y_train, order=sorted(y_train.unique()))
plt.title('Training Set')

# Plot for testing set
plt.subplot(1, 2, 2)  # 1 row, 2 columns, and the second plot
sns.countplot(x=y_test, order=sorted(y_test.unique()))
plt.title('Testing Set')

plt.show()

# %%
# Map categories to integers
category_mapping = {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5}

y_train = y_train.map(category_mapping)
y_test = y_test.map(category_mapping)

# %% [markdown]
# Have you thought about further normalising your time series? In the end, they are only scaled between 0 and 1. Speaking of which, ever heard of robust scalers? (PS: remember to de-normalise in the prediction function).

# %%
from sklearn.preprocessing import RobustScaler

# Initialize the RobustScaler
scaler = RobustScaler()

# Fit the scaler on the training data and transform both training and testing data
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.utils import to_categorical

forecasting_period_phase1 = 9
forecasting_period_phase2 = 18

y_train = to_categorical(y_train, num_classes=forecasting_period_phase1)
y_test = to_categorical(y_test, num_classes=forecasting_period_phase1)

# %% [markdown]
# # Build and train models

# %%
input_shape = X_train.shape[1:]
classes = y_train.shape[-1]
batch_size = 128
epochs = 200

forecasting_period_phase1 = 9
forecasting_period_phase2 = 18

input_shape, classes, X_train.shape
# Out:
# ((2776,), 9, (38400, 2776))

# %% [markdown]
# # Vanilla LSTM

# %%
import tensorflow.keras as tfk
import tensorflow.keras.layers as tfkl

def build_forecasting_model(input_shape, forecasting_period):
    # Input layer for categorical features
    input_layer = tfkl.Input(shape=(input_shape[0],), name='Input')  # Assuming input_shape is (num_features,)
    masking_layer = tfkl.Masking(mask_value=0.0)(input_layer)

    # Dense layers for feature extraction
    dense1 = tfkl.Dense(128, activation='relu')(masking_layer)
    dense2 = tfkl.Dense(128, activation='relu')(dense1)
    dropout = tfkl.Dropout(0.5, seed=42)(dense2)

    # Dense layer for classification
    classifier = tfkl.Dense(128, activation='relu')(dropout)
    
    # Forecasting layer
    forecasting_output = tfkl.Dense(forecasting_period, activation='softmax')(classifier)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=forecasting_output, name='forecasting_model')

    # Compile the model
    #model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics='accuracy')
    model.compile(loss=tfk.losses.MeanAbsoluteError(), optimizer=tfk.optimizers.Adam(), metrics=['mse'])

    # Return the model
    return model

# %%
# Build the forecasting model for Phase 1
model = build_forecasting_model(input_shape, classes)
model.summary()
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Model: "forecasting_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 2776)]            0
#
#  masking (Masking)           (None, 2776)              0
#
#  dense (Dense)               (None, 128)               355456
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dense_3 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 389641 (1.49 MB)
# Trainable params: 389641 (1.49 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = X_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_split=.1,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=10, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=5, factor=0.5, min_lr=1e-5)
    ]
).history
# Out:
# Epoch 1/200
# 270/270 [==============================] - 4s 12ms/step - loss: 0.1542 - mse: 0.1455 - val_loss: 0.1489 - val_mse: 0.1467 - lr: 0.0010
# Epoch 2/200
# 270/270 [==============================] - 2s 9ms/step - loss: 0.1469 - mse: 0.1446 - val_loss: 0.1486 - val_mse: 0.1466 - lr: 0.0010
# Epoch 3/200
# 270/270 [==============================] - 2s 9ms/step - loss: 0.1459 - mse: 0.1444 - val_loss: 0.1476 - val_mse: 0.1464 - lr: 0.0010
# Epoch 4/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1456 - mse: 0.1445 - val_loss: 0.1454 - val_mse: 0.1443 - lr: 0.0010
# Epoch 5/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1459 - mse: 0.1450 - val_loss: 0.1488 - val_mse: 0.1481 - lr: 0.0010
# Epoch 6/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1459 - mse: 0.1452 - val_loss: 0.1476 - val_mse: 0.1471 - lr: 0.0010
# Epoch 7/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1473 - mse: 0.1468 - val_loss: 0.1488 - val_mse: 0.1483 - lr: 0.0010
# Epoch 8/200
# 270/270 [==============================] - 2s 9ms/step - loss: 0.1487 - mse: 0.1484 - val_loss: 0.1531 - val_mse: 0.1529 - lr: 0.0010
# Epoch 9/200
# 270/270 [==============================] - 2s 9ms/step - loss: 0.1478 - mse: 0.1475 - val_loss: 0.1490 - val_mse: 0.1487 - lr: 0.0010
# Epoch 10/200
# 270/270 [==============================] - 2s 9ms/step - loss: 0.1452 - mse: 0.1449 - val_loss: 0.1436 - val_mse: 0.1432 - lr: 5.0000e-04
# Epoch 11/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1442 - mse: 0.1439 - val_loss: 0.1462 - val_mse: 0.1458 - lr: 5.0000e-04
# Epoch 12/200
# 270/270 [==============================] - 2s 9ms/step - loss: 0.1441 - mse: 0.1439 - val_loss: 0.1450 - val_mse: 0.1447 - lr: 5.0000e-04
# Epoch 13/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1447 - mse: 0.1444 - val_loss: 0.1412 - val_mse: 0.1410 - lr: 5.0000e-04
# Epoch 14/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1432 - mse: 0.1429 - val_loss: 0.1427 - val_mse: 0.1424 - lr: 5.0000e-04
# Epoch 15/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1417 - mse: 0.1415 - val_loss: 0.1437 - val_mse: 0.1435 - lr: 5.0000e-04
# Epoch 16/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1429 - mse: 0.1427 - val_loss: 0.1431 - val_mse: 0.1429 - lr: 5.0000e-04
# Epoch 17/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1406 - mse: 0.1404 - val_loss: 0.1428 - val_mse: 0.1427 - lr: 5.0000e-04
# Epoch 18/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1408 - mse: 0.1406 - val_loss: 0.1423 - val_mse: 0.1420 - lr: 5.0000e-04
# Epoch 19/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1389 - mse: 0.1387 - val_loss: 0.1398 - val_mse: 0.1395 - lr: 2.5000e-04
# Epoch 20/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1385 - mse: 0.1383 - val_loss: 0.1399 - val_mse: 0.1396 - lr: 2.5000e-04
# Epoch 21/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1381 - mse: 0.1379 - val_loss: 0.1384 - val_mse: 0.1382 - lr: 2.5000e-04
# Epoch 22/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1368 - mse: 0.1366 - val_loss: 0.1388 - val_mse: 0.1386 - lr: 2.5000e-04
# Epoch 23/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1375 - mse: 0.1372 - val_loss: 0.1393 - val_mse: 0.1391 - lr: 2.5000e-04
# Epoch 24/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1372 - mse: 0.1370 - val_loss: 0.1394 - val_mse: 0.1391 - lr: 2.5000e-04
# Epoch 25/200
# 270/270 [==============================] - 2s 9ms/step - loss: 0.1368 - mse: 0.1366 - val_loss: 0.1386 - val_mse: 0.1384 - lr: 2.5000e-04
# Epoch 26/200
# 270/270 [==============================] - 3s 10ms/step - loss: 0.1367 - mse: 0.1365 - val_loss: 0.1392 - val_mse: 0.1390 - lr: 2.5000e-04
# Epoch 27/200
# 270/270 [==============================] - 2s 9ms/step - loss: 0.1366 - mse: 0.1364 - val_loss: 0.1385 - val_mse: 0.1383 - lr: 1.2500e-04
# Epoch 28/200
# 270/270 [==============================] - 2s 9ms/step - loss: 0.1365 - mse: 0.1363 - val_loss: 0.1383 - val_mse: 0.1381 - lr: 1.2500e-04
# Epoch 29/200
# 270/270 [==============================] - 2s 9ms/step - loss: 0.1359 - mse: 0.1357 - val_loss: 0.1374 - val_mse: 0.1373 - lr: 1.2500e-04
# Epoch 30/200
# 270/270 [==============================] - 2s 9ms/step - loss: 0.1360 - mse: 0.1358 - val_loss: 0.1366 - val_mse: 0.1363 - lr: 1.2500e-04
# Epoch 31/200
# 270/270 [==============================] - 2s 9ms/step - loss: 0.1359 - mse: 0.1357 - val_loss: 0.1375 - val_mse: 0.1374 - lr: 1.2500e-04
# Epoch 32/200
# 270/270 [==============================] - 2s 9ms/step - loss: 0.1358 - mse: 0.1356 - val_loss: 0.1374 - val_mse: 0.1372 - lr: 1.2500e-04
# Epoch 33/200
# 270/270 [==============================] - 2s 9ms/step - loss: 0.1362 - mse: 0.1360 - val_loss: 0.1367 - val_mse: 0.1365 - lr: 1.2500e-04
# Epoch 34/200
# 270/270 [==============================] - 2s 9ms/step - loss: 0.1358 - mse: 0.1356 - val_loss: 0.1360 - val_mse: 0.1359 - lr: 1.2500e-04
# Epoch 35/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1358 - mse: 0.1356 - val_loss: 0.1369 - val_mse: 0.1367 - lr: 1.2500e-04
# Epoch 36/200
# 270/270 [==============================] - 2s 9ms/step - loss: 0.1362 - mse: 0.1359 - val_loss: 0.1360 - val_mse: 0.1358 - lr: 1.2500e-04
# Epoch 37/200
# 270/270 [==============================] - 2s 9ms/step - loss: 0.1352 - mse: 0.1349 - val_loss: 0.1353 - val_mse: 0.1350 - lr: 1.2500e-04
# Epoch 38/200
# 270/270 [==============================] - 2s 9ms/step - loss: 0.1345 - mse: 0.1342 - val_loss: 0.1357 - val_mse: 0.1355 - lr: 1.2500e-04
# Epoch 39/200
# 270/270 [==============================] - 2s 9ms/step - loss: 0.1349 - mse: 0.1346 - val_loss: 0.1361 - val_mse: 0.1360 - lr: 1.2500e-04
# Epoch 40/200
# 270/270 [==============================] - 3s 10ms/step - loss: 0.1349 - mse: 0.1347 - val_loss: 0.1366 - val_mse: 0.1364 - lr: 1.2500e-04
# Epoch 41/200
# 270/270 [==============================] - 2s 9ms/step - loss: 0.1347 - mse: 0.1345 - val_loss: 0.1356 - val_mse: 0.1354 - lr: 1.2500e-04
# Epoch 42/200
# 270/270 [==============================] - 2s 9ms/step - loss: 0.1349 - mse: 0.1347 - val_loss: 0.1350 - val_mse: 0.1347 - lr: 1.2500e-04
# Epoch 43/200
# 270/270 [==============================] - 2s 9ms/step - loss: 0.1342 - mse: 0.1340 - val_loss: 0.1348 - val_mse: 0.1346 - lr: 1.2500e-04
# Epoch 44/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1343 - mse: 0.1341 - val_loss: 0.1354 - val_mse: 0.1352 - lr: 1.2500e-04
# Epoch 45/200
# 270/270 [==============================] - 2s 9ms/step - loss: 0.1345 - mse: 0.1343 - val_loss: 0.1355 - val_mse: 0.1354 - lr: 1.2500e-04
# Epoch 46/200
# 270/270 [==============================] - 3s 9ms/step - loss: 0.1347 - mse: 0.1345 - val_loss: 0.1366 - val_mse: 0.1364 - lr: 1.2500e-04
# Epoch 47/200
# 270/270 [==============================] - 2s 9ms/step - loss: 0.1346 - mse: 0.1344 - val_loss: 0.1344 - val_mse: 0.1342 - lr: 1.2500e-04
# Epoch 48/200
# 270/270 [==============================] - 3s 10ms/step - loss: 0.1340 - mse: 0.1338 - val_loss: 0.1357 - val_mse: 0.1355 - lr: 1.2500e-04
# Epoch 49/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1341 - mse: 0.1339 - val_loss: 0.1350 - val_mse: 0.1347 - lr: 1.2500e-04
# Epoch 50/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1341 - mse: 0.1338 - val_loss: 0.1356 - val_mse: 0.1353 - lr: 1.2500e-04
# Epoch 51/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1341 - mse: 0.1339 - val_loss: 0.1358 - val_mse: 0.1357 - lr: 1.2500e-04
# Epoch 52/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1340 - mse: 0.1338 - val_loss: 0.1346 - val_mse: 0.1343 - lr: 1.2500e-04
# Epoch 53/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1334 - mse: 0.1331 - val_loss: 0.1341 - val_mse: 0.1339 - lr: 6.2500e-05
# Epoch 54/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1333 - mse: 0.1331 - val_loss: 0.1347 - val_mse: 0.1344 - lr: 6.2500e-05
# Epoch 55/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1337 - mse: 0.1336 - val_loss: 0.1340 - val_mse: 0.1339 - lr: 6.2500e-05
# Epoch 56/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1335 - mse: 0.1333 - val_loss: 0.1338 - val_mse: 0.1337 - lr: 6.2500e-05
# Epoch 57/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1331 - mse: 0.1329 - val_loss: 0.1340 - val_mse: 0.1337 - lr: 6.2500e-05
# Epoch 58/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1333 - mse: 0.1330 - val_loss: 0.1339 - val_mse: 0.1337 - lr: 6.2500e-05
# Epoch 59/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1332 - mse: 0.1330 - val_loss: 0.1343 - val_mse: 0.1341 - lr: 6.2500e-05
# Epoch 60/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1336 - mse: 0.1334 - val_loss: 0.1350 - val_mse: 0.1349 - lr: 6.2500e-05
# Epoch 61/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1333 - mse: 0.1331 - val_loss: 0.1335 - val_mse: 0.1333 - lr: 6.2500e-05
# Epoch 62/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1332 - mse: 0.1330 - val_loss: 0.1329 - val_mse: 0.1327 - lr: 6.2500e-05
# Epoch 63/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1333 - mse: 0.1331 - val_loss: 0.1343 - val_mse: 0.1341 - lr: 6.2500e-05
# Epoch 64/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1326 - mse: 0.1324 - val_loss: 0.1340 - val_mse: 0.1338 - lr: 6.2500e-05
# Epoch 65/200
# 270/270 [==============================] - 2s 9ms/step - loss: 0.1328 - mse: 0.1326 - val_loss: 0.1342 - val_mse: 0.1340 - lr: 6.2500e-05
# Epoch 66/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1329 - mse: 0.1327 - val_loss: 0.1344 - val_mse: 0.1341 - lr: 6.2500e-05
# Epoch 67/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1328 - mse: 0.1326 - val_loss: 0.1340 - val_mse: 0.1339 - lr: 6.2500e-05
# Epoch 68/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1332 - mse: 0.1330 - val_loss: 0.1343 - val_mse: 0.1341 - lr: 3.1250e-05
# Epoch 69/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1330 - mse: 0.1328 - val_loss: 0.1341 - val_mse: 0.1339 - lr: 3.1250e-05
# Epoch 70/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1326 - mse: 0.1324 - val_loss: 0.1338 - val_mse: 0.1336 - lr: 3.1250e-05
# Epoch 71/200
# 270/270 [==============================] - 2s 9ms/step - loss: 0.1326 - mse: 0.1323 - val_loss: 0.1341 - val_mse: 0.1339 - lr: 3.1250e-05
# Epoch 72/200
# 270/270 [==============================] - 2s 8ms/step - loss: 0.1327 - mse: 0.1324 - val_loss: 0.1337 - val_mse: 0.1335 - lr: 3.1250e-05

# %% [markdown]
# Is it possible, and does it make sense to build a ResNet-style model with Conv1Ds?

# %% [markdown]
# If you want to give a more robust interpretation of the results, given the individual normalisation of the series, you can consider the Mean Absolute Error (MAE) as the average percentage error (scaled between 0 and 1) obtained on the predicted points compared to the ground truth.

# %% [markdown]
# # Plot results

# %%
# Plot results

best_epoch = np.argmin(history['val_loss'])
plt.figure(figsize=(17,4))
plt.plot(history['loss'], label='Training loss', alpha=.8, color='#ff7f0e')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Mean Squared Error (Loss)')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['mse'], label='Training accuracy', alpha=.8, color='#ff7f0e')
plt.plot(history['val_mse'], label='Validation accuracy', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Mean Absolute Error')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(18,3))
plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='#ff7f0e')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
# Predict the test set 
predictions = model.predict(X_test)
print(predictions.shape)

mean_squared_error = tfk.metrics.mse(y_test.flatten(),predictions.flatten())
mean_absolute_error = tfk.metrics.mae(y_test.flatten(),predictions.flatten())
mean_squared_error, mean_absolute_error
# Out:
# 300/300 [==============================] - 1s 3ms/step
# (9600, 9)
# (<tf.Tensor: shape=(), dtype=float32, numpy=0.13714747>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.13729522>)

# %%
predictions.shape
target_labels = categories_df

# %%
def inspect_multivariate_prediction(X, y, pred, columns, telescope, idx=None):
    if(idx==None):
        idx=np.random.randint(0,len(X))

    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(np.arange(len(X[0,:,i])), X[idx,:,i])
        axs[i].plot(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), y[idx,:,i], color='orange')
        axs[i].plot(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), pred[idx,:,i], color='green') 
        # le linee verdi hanno dei segmenti che sono sovrascitti, poiché i samples in X_test sono sovrappost (visto che stride != window)
        axs[i].set_title(col)
        axs[i].set_ylim(0,1)
    plt.show()
    
# inspect_multivariate_prediction(X_test, y_test, predictions, target_labels, forecasting_period_phase1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 15
#      12         axs[i].set_ylim(0,1)
#      13     plt.show()
# ---> 15 inspect_multivariate_prediction(X_test, y_test, predictions, target_labels, forecasting_period_phase1)
#
# Cell In[27], line 5, in inspect_multivariate_prediction(X, y, pred, columns, telescope, idx)
#       2 if(idx==None):
#       3     idx=np.random.randint(0,len(X))
# ----> 5 figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
#       6 for i, col in enumerate(columns):
#       7     axs[i].plot(np.arange(len(X[0,:,i])), X[idx,:,i])
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ANN/lib/python3.10/site-packages/matplotlib/pyplot.py:1599, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1455 """
#    1456 Create a figure and a set of subplots.
#    1457
#    (...)
#    1596
#    1597 """
#    1598 fig = figure(**fig_kw)
# -> 1599 axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1600                    squeeze=squeeze, subplot_kw=subplot_kw,
#    1601                    gridspec_kw=gridspec_kw, height_ratios=height_ratios,
#    1602                    width_ratios=width_ratios)
#    1603 return fig, axs
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ANN/lib/python3.10/site-packages/matplotlib/figure.py:931, in FigureBase.subplots(self, nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw)
#     928     gridspec_kw['width_ratios'] = width_ratios
#     930 gs = self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
# --> 931 axs = gs.subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#     932                   subplot_kw=subplot_kw)
#     933 return axs
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ANN/lib/python3.10/site-packages/matplotlib/gridspec.py:298, in GridSpecBase.subplots(self, sharex, sharey, squeeze, subplot_kw)
#     296         subplot_kw["sharex"] = shared_with[sharex]
#     297         subplot_kw["sharey"] = shared_with[sharey]
# --> 298         axarr[row, col] = figure.add_subplot(
#     299             self[row, col], **subplot_kw)
#     301 # turn off redundant tick labeling
#     302 if sharex in ["col", "all"]:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ANN/lib/python3.10/site-packages/matplotlib/figure.py:782, in FigureBase.add_subplot(self, *args, **kwargs)
#     780         args = tuple(map(int, str(args[0])))
#     781     projection_class, pkw = self._process_projection_requirements(**kwargs)
# --> 782     ax = projection_class(self, *args, **pkw)
#     783     key = (projection_class, pkw)
#     784 return self._add_axes_internal(ax, key)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ANN/lib/python3.10/site-packages/matplotlib/axes/_base.py:678, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, *args, **kwargs)
#     675 self.set_axisbelow(mpl.rcParams['axes.axisbelow'])
#     677 self._rasterization_zorder = None
# --> 678 self.clear()
#     680 # funcs used to format x and y - fall back on major formatters
#     681 self.fmt_xdata = None
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ANN/lib/python3.10/site-packages/matplotlib/axes/_base.py:1388, in _AxesBase.clear(self)
#    1386     self.cla()
#    1387 else:
# -> 1388     self.__clear()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ANN/lib/python3.10/site-packages/matplotlib/axes/_base.py:1370, in _AxesBase.__clear(self)
#    1368 share = getattr(self, f"_share{name}")
#    1369 if share is not None:
# -> 1370     getattr(self, f"share{name}")(share)
#    1371 else:
#    1372     # Although the scale was set to linear as part of clear,
#    1373     # polar requires that _set_scale is called again
#    1374     if self.name == "polar":
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ANN/lib/python3.10/site-packages/matplotlib/axes/_base.py:1232, in _AxesBase.sharex(self, other)
#    1230 self.xaxis.minor = other.xaxis.minor  # locator and formatter.
#    1231 x0, x1 = other.get_xlim()
# -> 1232 self.set_xlim(x0, x1, emit=False, auto=other.get_autoscalex_on())
#    1233 self.xaxis._scale = other.xaxis._scale
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ANN/lib/python3.10/site-packages/matplotlib/axes/_base.py:3664, in _AxesBase.set_xlim(self, left, right, emit, auto, xmin, xmax)
#    3662         raise TypeError("Cannot pass both 'right' and 'xmax'")
#    3663     right = xmax
# -> 3664 return self.xaxis._set_lim(left, right, emit=emit, auto=auto)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ANN/lib/python3.10/site-packages/matplotlib/axis.py:1243, in Axis._set_lim(self, v0, v1, emit, auto)
#    1240 v0, v1 = self.limit_range_for_scale(v0, v1)
#    1241 v0, v1 = sorted([v0, v1], reverse=bool(reverse))
# -> 1243 self.set_view_interval(v0, v1, ignore=True)
#    1244 # Mark viewlims as no longer stale without triggering an autoscale.
#    1245 for ax in self._get_shared_axes():
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ANN/lib/python3.10/site-packages/matplotlib/axis.py:2272, in _make_getset_interval.<locals>.setter(self, vmin, vmax, ignore)
#    2269 def setter(self, vmin, vmax, ignore=False):
#    2270     # docstring inherited.
#    2271     if ignore:
# -> 2272         setattr(getattr(self.axes, lim_name), attr_name, (vmin, vmax))
#    2273     else:
#    2274         oldmin, oldmax = getter(self)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ANN/lib/python3.10/site-packages/matplotlib/axes/_base.py:849, in _AxesBase.viewLim(self)
#     847 @property
#     848 def viewLim(self):
# --> 849     self._unstale_viewLim()
#     850     return self._viewLim
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ANN/lib/python3.10/site-packages/matplotlib/axes/_base.py:836, in _AxesBase._unstale_viewLim(self)
#     833 def _unstale_viewLim(self):
#     834     # We should arrange to store this information once per share-group
#     835     # instead of on every axis.
# --> 836     need_scale = {
#     837         name: any(ax._stale_viewlims[name]
#     838                   for ax in self._shared_axes[name].get_siblings(self))
#     839         for name in self._axis_names}
#     840     if any(need_scale.values()):
#     841         for name in need_scale:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ANN/lib/python3.10/site-packages/matplotlib/axes/_base.py:837, in <dictcomp>(.0)
#     833 def _unstale_viewLim(self):
#     834     # We should arrange to store this information once per share-group
#     835     # instead of on every axis.
#     836     need_scale = {
# --> 837         name: any(ax._stale_viewlims[name]
#     838                   for ax in self._shared_axes[name].get_siblings(self))
#     839         for name in self._axis_names}
#     840     if any(need_scale.values()):
#     841         for name in need_scale:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ANN/lib/python3.10/site-packages/matplotlib/axes/_base.py:837, in <genexpr>(.0)
#     833 def _unstale_viewLim(self):
#     834     # We should arrange to store this information once per share-group
#     835     # instead of on every axis.
#     836     need_scale = {
# --> 837         name: any(ax._stale_viewlims[name]
#     838                   for ax in self._shared_axes[name].get_siblings(self))
#     839         for name in self._axis_names}
#     840     if any(need_scale.values()):
#     841         for name in need_scale:
#
# KeyboardInterrupt:

# %%
# Compute the confusion matrix

cm = confusion_matrix(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))

cm = cm /cm.astype(float).sum(axis=1);

# Compute the classification metrics
accuracy = accuracy_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(cm.T, cmap='Blues', annot=True, annot_kws={'fontsize':9,'alpha':0.6})#, xticklabels=list(label_mapping.keys()), yticklabels=list(label_mapping.keys()))
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()

# %% [markdown]
# # Save the model

# %%
model.save('SubmissionModel')
shutil.make_archive("SubmissionModel", 'zip', "./SubmissionModel")

# %%
import os
import zipfile
from datetime import datetime
import tensorflow as tf
from os.path import basename

# Specify the name of the submission folder
submission_folder = "SubmissionModel"

# Save best epoch model
model.save(os.path.join(submission_folder, "SubmissionModel"))

# Save the model.py file in the main directory
with open("model.py", "w") as model_file:
    model_file.write("""

import os
import tensorflow as tf
import numpy as np

class model:
    def __init__(self, path):
        self.model = tf.keras.models.load_model(os.path.join(path, 'SubmissionModel'))

    def predict(self, X, categories):
        # Determine the number of zeros to add
        num_zeros_to_add = 2776 - X.shape[1]

        # Add zeros to the beginning of each sequence in X
        X_padded = np.pad(X, ((0, 0), (num_zeros_to_add, 0)), mode='constant')

        # Note: this is just an example.
        # Here the model.predict is called
        out = self.model.predict(X_padded)  # Shape [BSx9] for Phase 1 and [BSx18] for Phase 2

        return out
""")

# Create an empty metadata file in the main directory
open("metadata", "w").close()

# Get the current date and time
current_datetime = datetime.now()
formatted_datetime = current_datetime.strftime("%Y%m%d_%H%M%S")

# Create the zipfile with date and time in the name
zipfile_name = f"{submission_folder}_{formatted_datetime}.zip"

with zipfile.ZipFile(zipfile_name, 'w') as zip_file:
    # Add the entire "SubmissionModel" folder and its contents to the archive
    for foldername, subfolders, filenames in os.walk(submission_folder):
        for filename in filenames:
            file_path = os.path.join(foldername, filename)
            arcname = os.path.relpath(file_path, submission_folder)

            if (foldername in ["SubmissionModel", "SubmissionModel/model", "SubmissionModel/model/variables", "SubmissionModel/variables"]):
                continue

            # print(foldername)
            print(file_path)

            zip_file.write(file_path, arcname)

    # Add other files to the archive (model.py and metadata)
    zip_file.write("model.py", arcname="model.py")
    zip_file.write("metadata", arcname="metadata")

print(zipfile_name)
