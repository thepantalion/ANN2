# %%
import numpy as np

# Load the numpy array from the file
data = np.load('/kaggle/input/training/training_data.npy')
valid_periods = np.load('/kaggle/input/training/valid_periods.npy')
data.shape
# Out:
# (48000, 2776)

# %%
# Calculate the number of valid points for each function
num_valid_points = valid_periods[:, 1] - valid_periods[:, 0] + 1

# Filter out functions with less than 210 valid points
filtered_data = data[num_valid_points >= 210]

# Check the shape of the filtered data
print(filtered_data.shape)
data = filtered_data
# Out:
# (21970, 2776)

# %%
# Shuffle the datasets in unison
perm = np.random.permutation(data.shape[0])
data_shuffled = data[perm]
valid_periods_shuffled = valid_periods[perm]

K = 7500
# Split into training and validation sets
validation_data = data_shuffled[:K]
validation_periods = valid_periods_shuffled[:K]

training_data = data_shuffled[K:]
training_periods = valid_periods_shuffled[K:]

# %%
def apply_valid_periods(data, valid_periods):
    """
    Modify each function in 'data' based on the corresponding 'valid_periods'.

    Parameters:
    data (numpy.ndarray): Array of functions, shape (n_samples, n_features).
    valid_periods (numpy.ndarray): Array of valid periods, shape (n_samples, 2).

    Returns:
    numpy.ndarray: Modified data array.
    """
    modified_data = np.zeros_like(data)
    n_samples, n_features = data.shape

    for i in range(n_samples):
        left, right = valid_periods[i]
        # Assuming 'left' and 'right' are indices in the range [0, n_features-1]
        # Adjust them if they are in a different format
        modified_data[i, left:right+1] = data[i, left:right+1]

    return modified_data

# Apply the function to your datasets
modified_training_data = apply_valid_periods(training_data, training_periods)
modified_validation_data = apply_valid_periods(validation_data, validation_periods)
#modified_test_data = apply_valid_periods(test_data, test_periods)

# %%
modified_training_data.shape
# Out:
# (14470, 2776)

# %%
import numpy as np

def extract_non_overlapping_intervals(data, training_periods, interval_length=209):
    """
    Extracts non-overlapping intervals of length `interval_length` from valid periods of each function.
    
    Parameters:
    data (numpy.ndarray): Array of functions, shape (n_samples, n_features).
    training_periods (numpy.ndarray): Array of valid periods, shape (n_samples, 2).
    interval_length (int): Length of the interval to extract.

    Returns:
    numpy.ndarray: A 2D array with shape (num_intervals, interval_length).
    """
    all_intervals = []

    for function, (left, right) in zip(data, training_periods):
        # Adjust right boundary to ensure intervals fit within the range
        right = min(right, len(function))

        # Extract intervals within the valid period
        for start_idx in range(left, right, interval_length):
            end_idx = min(start_idx + interval_length, right)
            interval = function[start_idx:end_idx]

            # Pad the interval if it's shorter than the interval length
            if len(interval) < interval_length:
                interval = np.pad(interval, (0, interval_length - len(interval)), 'constant')

            all_intervals.append(interval)

    return np.array(all_intervals)

# Example usage
final_training_data = extract_non_overlapping_intervals(modified_training_data, training_periods)
final_validation_data = extract_non_overlapping_intervals(modified_validation_data, validation_periods)
# final_test_data = extract_non_overlapping_intervals(modified_test_data, test_periods)

# %%
final_training_data.shape
# Out:
# (21879, 209)

# %%
import tensorflow as tf
import joblib
encoder = tf.keras.models.load_model('/kaggle/input/models/encoder_model.h5')
svm = joblib.load('/kaggle/input/models/svm_model.joblib')

# %%
# Assuming final_training_data and final_validation_data have shape (n_samples, 209)
# and you want to select the first 200 columns
X_train_modified = final_training_data[:, :200]
X_val_modified = final_validation_data[:, :200]


def predict_cluster(encoder, svm, data):
    """
    Predict cluster assignments using an encoder and SVM classifier.

    Parameters:
    encoder (tf.keras.Model): Trained Keras encoder model.
    svm (sklearn.svm.SVC or similar): Trained SVM classifier.
    data (numpy.ndarray): Data to be clustered, shape (n_samples, n_features).

    Returns:
    numpy.ndarray: Cluster assignments.
    """
    # Assuming the encoder expects data with an additional dimension
    data_reshaped = data.reshape((data.shape[0], data.shape[1], 1))

    # Encode the data
    encoded_data = encoder.predict(data_reshaped)

    # Flatten the encoded data if necessary (depends on encoder's output shape)
    if len(encoded_data.shape) > 2:
        encoded_data = encoded_data.reshape((encoded_data.shape[0], -1))

    # Predict probabilities
    #probabilities = svm.predict_proba(encoded_data)

    # Select the most probable cluster among the first four
    #cluster_assignments = np.argmax(probabilities[:, :4], axis=1)
    # Use the SVM classifier to predict clusters
    cluster_assignments = svm.predict(encoded_data)

    return cluster_assignments


# Assuming you have an 'encoder' and a 'classifier'
# and a function 'predict_cluster' that returns cluster assignments
cluster_assignments_train = predict_cluster(encoder, svm, X_train_modified)
#cluster_assignments_train[:] = 0
cluster_assignments_val = predict_cluster(encoder, svm, X_val_modified)
#cluster_assignments_val[:] = 0

def split_data_by_clusters(original_data, clusters):
    cluster_data = {}
    for cluster in set(clusters):
        cluster_data[cluster] = original_data[clusters == cluster]
    return cluster_data

# final_training_data and final_validation_data have the original shape (something, 209)
training_data_by_cluster = split_data_by_clusters(final_training_data, cluster_assignments_train)
validation_data_by_cluster = split_data_by_clusters(final_validation_data, cluster_assignments_val)
# Out:
# 684/684 [==============================] - 1s 1ms/step
# 357/357 [==============================] - 0s 1ms/step

# %%
import numpy as np
from collections import Counter

# Assuming cluster_assignments_train is your array
# cluster_assignments_train = np.array([...])  # Your array here

# Count occurrences using NumPy
unique, counts = np.unique(cluster_assignments_train, return_counts=True)
cluster_counts = dict(zip(unique, counts))

# Alternatively, using collections.Counter
# cluster_counts = Counter(cluster_assignments_train)

print(cluster_counts)
# Out:
# {0: 1443, 1: 573, 2: 746, 3: 1053, 4: 5810, 5: 779, 6: 2352, 7: 1246, 8: 7877}

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping, TerminateOnNaN
import tensorflow as tf

def train_model_for_cluster(full_train_cluster_data, full_val_cluster_data, epochs=50, batch_size=512):
    """
    Train a neural network model for a specific data cluster, predicting the last 9 points.

    Parameters:
    full_train_cluster_data (numpy.ndarray): Full training data for the cluster.
    full_val_cluster_data (numpy.ndarray): Full validation data for the cluster.
    epochs (int): Number of epochs to train.
    batch_size (int): Batch size for training.

    Returns:
    tf.keras.Model: Trained Keras model.
    """

    # Split data into features (X) and labels (y)
    print(full_train_cluster_data.shape, full_val_cluster_data.shape)
    X_train_cluster = full_train_cluster_data[:, :-9]
    y_train_cluster = full_train_cluster_data[:, -9:]
    X_val_cluster = full_val_cluster_data[:, :-9]
    y_val_cluster = full_val_cluster_data[:, -9:]

    # Define the model architecture
    model = Sequential()
    model.add(LSTM(50, activation='relu', input_shape=(X_train_cluster.shape[1], 1)))
    model.add(Dense(9))  # Predicting 9 points

    # Compile the model
    optimizer = SGD(lr=0.001)  # Using a lower learning rate with gradient clipping
    model.compile(optimizer=optimizer, loss='mse')

    # Reshape data for LSTM
    X_train_reshaped = X_train_cluster.reshape((X_train_cluster.shape[0], X_train_cluster.shape[1], 1))
    X_val_reshaped = X_val_cluster.reshape((X_val_cluster.shape[0], X_val_cluster.shape[1], 1))

    # Define callbacks
    early_stopping = EarlyStopping(monitor='mse', patience=10)
    terminate_on_nan = TerminateOnNaN()

    # Train the model
    model.fit(X_train_reshaped, y_train_cluster, validation_data=(X_val_reshaped, y_val_cluster), epochs=epochs, batch_size=batch_size, callbacks=[early_stopping, terminate_on_nan])

    return model

# %%
models_by_cluster = {}
for cluster in training_data_by_cluster:
    models_by_cluster[cluster] = train_model_for_cluster(training_data_by_cluster[cluster], validation_data_by_cluster[cluster])
# Out:
# (1443, 209) (758, 209)
# Epoch 1/50
# 3/3 [==============================] - 2s 404ms/step - loss: 0.3968 - val_loss: 0.3722
# Epoch 2/50
# 3/3 [==============================] - 1s 300ms/step - loss: 0.3798 - val_loss: 0.3555
# Epoch 3/50
# 3/3 [==============================] - 1s 292ms/step - loss: 0.3628 - val_loss: 0.3394
# Epoch 4/50
# 3/3 [==============================] - 1s 295ms/step - loss: 0.3467 - val_loss: 0.3245
# Epoch 5/50
# 3/3 [==============================] - 1s 296ms/step - loss: 0.3318 - val_loss: 0.3108
# Epoch 6/50
# 3/3 [==============================] - 1s 297ms/step - loss: 0.3179 - val_loss: 0.2977
# Epoch 7/50
# 3/3 [==============================] - 1s 294ms/step - loss: 0.3047 - val_loss: 0.2855
# Epoch 8/50
# 3/3 [==============================] - 1s 296ms/step - loss: 0.2925 - val_loss: 0.2741
# Epoch 9/50
# 3/3 [==============================] - 1s 300ms/step - loss: 0.2810 - val_loss: 0.2632
# Epoch 10/50
# 3/3 [==============================] - 1s 293ms/step - loss: 0.2699 - val_loss: 0.2527
# Epoch 11/50
# 3/3 [==============================] - 1s 294ms/step - loss: 0.2592 - val_loss: 0.2425
# Epoch 12/50
# 3/3 [==============================] - 1s 297ms/step - loss: 0.2488 - val_loss: 0.2326
# Epoch 13/50
# 3/3 [==============================] - 1s 301ms/step - loss: 0.2387 - val_loss: 0.2230
# Epoch 14/50
# 3/3 [==============================] - 1s 308ms/step - loss: 0.2288 - val_loss: 0.2136
# Epoch 15/50
# 3/3 [==============================] - 1s 300ms/step - loss: 0.2192 - val_loss: 0.2044
# Epoch 16/50
# 3/3 [==============================] - 1s 294ms/step - loss: 0.2097 - val_loss: 0.1953
# Epoch 17/50
# 3/3 [==============================] - 1s 291ms/step - loss: 0.2004 - val_loss: 0.1865
# Epoch 18/50
# 3/3 [==============================] - 1s 294ms/step - loss: 0.1913 - val_loss: 0.1777
# Epoch 19/50
# 3/3 [==============================] - 1s 290ms/step - loss: 0.1823 - val_loss: 0.1691
# Epoch 20/50
# 3/3 [==============================] - 1s 334ms/step - loss: 0.1734 - val_loss: 0.1606
# Epoch 21/50
# 3/3 [==============================] - 1s 306ms/step - loss: 0.1646 - val_loss: 0.1523
# Epoch 22/50
# 3/3 [==============================] - 1s 291ms/step - loss: 0.1560 - val_loss: 0.1441
# Epoch 23/50
# 3/3 [==============================] - 1s 293ms/step - loss: 0.1476 - val_loss: 0.1360
# Epoch 24/50
50
# 2/2 [==============================] - 1s 309ms/step - loss: 0.2187 - val_loss: 0.2035
# Epoch 39/50
# 2/2 [==============================] - 1s 305ms/step - loss: 0.2164 - val_loss: 0.2013
# Epoch 40/50
# 2/2 [==============================] - 1s 301ms/step - loss: 0.2140 - val_loss: 0.1991
# Epoch 41/50
# 2/2 [==============================] - 1s 309ms/step - loss: 0.2117 - val_loss: 0.1967
# Epoch 42/50
# 2/2 [==============================] - 1s 301ms/step - loss: 0.2092 - val_loss: 0.1946
# Epoch 43/50
# 2/2 [==============================] - 1s 313ms/step - loss: 0.2069 - val_loss: 0.1927
# Epoch 44/50
# 2/2 [==============================] - 1s 313ms/step - loss: 0.2049 - val_loss: 0.1906
# Epoch 45/50
# 2/2 [==============================] - 1s 311ms/step - loss: 0.2026 - val_loss: 0.1886
# Epoch 46/50
# 2/2 [==============================] - 1s 305ms/step - loss: 0.2005 - val_loss: 0.1865
# Epoch 47/50
# 2/2 [==============================] - 1s 304ms/step - loss: 0.1982 - val_loss: 0.1843
# Epoch 48/50
# 2/2 [==============================] - 1s 329ms/step - loss: 0.1959 - val_loss: 0.1824
# Epoch 49/50
# 2/2 [==============================] - 1s 300ms/step - loss: 0.1939 - val_loss: 0.1805
# Epoch 50/50
# 2/2 [==============================] - 1s 327ms/step - loss: 0.1918 - val_loss: 0.1785
# (746, 209) (348, 209)
# Epoch 1/50
# 2/2 [==============================] - 2s 528ms/step - loss: 0.3323 - val_loss: 0.3169
# Epoch 2/50
# 2/2 [==============================] - 1s 311ms/step - loss: 0.3261 - val_loss: 0.3110
# Epoch 3/50
# 2/2 [==============================] - 1s 347ms/step - loss: 0.3200 - val_loss: 0.3052
# Epoch 4/50
# 2/2 [==============================] - 1s 342ms/step - loss: 0.3141 - val_loss: 0.2998
# Epoch 5/50
# 2/2 [==============================] - 1s 307ms/step - loss: 0.3085 - val_loss: 0.2946
# Epoch 6/50
# 2/2 [==============================] - 1s 312ms/step - loss: 0.3031 - val_loss: 0.2894
# Epoch 7/50
# 2/2 [==============================] - 1s 307ms/step - loss: 0.2977 - val_loss: 0.2844
# Epoch 8/50
# 2/2 [==============================] - 1s 377ms/step - loss: 0.2925 - val_loss: 0.2796
# Epoch 9/50
# 2/2 [==============================] - 1s 347ms/step - loss: 0.2876 - val_loss: 0.2751
# Epoch 10/50
# 2/2 [==============================] - 1s 309ms/step - loss: 0.2829 - val_loss: 0.2708
# Epoch 11/50
# 2/2 [==============================] - 1s 311ms/step - loss: 0.2785 - val_loss: 0.2667
# Epoch 12/50
# 2/2 [==============================] - 1s 336ms/step - loss: 0.2743 - val_loss: 0.2629
# Epoch 13/50
# 2/2 [==============================] - 1s 311ms/step - loss: 0.2704 - val_loss: 0.2593
# Epoch 14/50
# 2/2 [==============================] - 1s 310ms/step - loss: 0.2666 - val_loss: 0.2558
# Epoch 15/50
# 2/2 [==============================] - 1s 308ms/step - loss: 0.2630 - val_loss: 0.2525
# Epoch 16/50
# 2/2 [==============================] - 1s 308ms/step - loss: 0.2596 - val_loss: 0.2493
# Epoch 17/50
# 2/2 [==============================] - 1s 313ms/step - loss: 0.2563 - val_loss: 0.2462
# Epoch 18/50
# 12/12 [==============================] - 3s 273ms/step - loss: 0.0309 - val_loss: 0.0330
# Epoch 43/50
# 12/12 [==============================] - 3s 289ms/step - loss: 0.0308 - val_loss: 0.0329
# Epoch 44/50
# 12/12 [==============================] - 3s 274ms/step - loss: 0.0307 - val_loss: 0.0328
# Epoch 45/50
# 12/12 [==============================] - 3s 284ms/step - loss: 0.0306 - val_loss: 0.0327
# Epoch 46/50
# 12/12 [==============================] - 3s 279ms/step - loss: 0.0305 - val_loss: 0.0326
# Epoch 47/50
# 12/12 [==============================] - 3s 272ms/step - loss: 0.0304 - val_loss: 0.0325
# Epoch 48/50
# 12/12 [==============================] - 3s 271ms/step - loss: 0.0303 - val_loss: 0.0324
# Epoch 49/50
# 12/12 [==============================] - 3s 276ms/step - loss: 0.0303 - val_loss: 0.0323
# Epoch 50/50
# 12/12 [==============================] - 3s 273ms/step - loss: 0.0302 - val_loss: 0.0322
# (779, 209) (411, 209)
# Epoch 1/50
# 2/2 [==============================] - 2s 512ms/step - loss: 0.5069 - val_loss: 0.4745
# Epoch 2/50
# 2/2 [==============================] - 1s 311ms/step - loss: 0.4914 - val_loss: 0.4599
# Epoch 3/50
# 2/2 [==============================] - 1s 309ms/step - loss: 0.4765 - val_loss: 0.4463
# Epoch 4/50
# 2/2 [==============================] - 1s 313ms/step - loss: 0.4628 - val_loss: 0.4335
# Epoch 5/50
# 2/2 [==============================] - 1s 309ms/step - loss: 0.4496 - val_loss: 0.4210
# Epoch 6/50
# 2/2 [==============================] - 1s 391ms/step - loss: 0.4369 - val_loss: 0.4093
# Epoch 7/50
# 2/2 [==============================] - 1s 324ms/step - loss: 0.4250 - val_loss: 0.3987
# Epoch 8/50
# 2/2 [==============================] - 1s 309ms/step - loss: 0.4143 - val_loss: 0.3894
# Epoch 9/50
# 2/2 [==============================] - 1s 305ms/step - loss: 0.4049 - val_loss: 0.3814
# Epoch 10/50
# 2/2 [==============================] - 1s 311ms/step - loss: 0.3968 - val_loss: 0.3744
# Epoch 11/50
# 2/2 [==============================] - 1s 306ms/step - loss: 0.3897 - val_loss: 0.3679
# Epoch 12/50
# 2/2 [==============================] - 1s 308ms/step - loss: 0.3829 - val_loss: 0.3615
# Epoch 13/50
# 2/2 [==============================] - 1s 305ms/step - loss: 0.3764 - val_loss: 0.3552
# Epoch 14/50
# 2/2 [==============================] - 1s 309ms/step - loss: 0.3699 - val_loss: 0.3490
# Epoch 15/50
# 2/2 [==============================] - 1s 308ms/step - loss: 0.3635 - val_loss: 0.3429
# Epoch 16/50
# 2/2 [==============================] - 1s 308ms/step - loss: 0.3572 - val_loss: 0.3368
# Epoch 17/50
# 2/2 [==============================] - 1s 307ms/step - loss: 0.3509 - val_loss: 0.3308
# Epoch 18/50
# 2/2 [==============================] - 1s 303ms/step - loss: 0.3447 - val_loss: 0.3248
# Epoch 19/50
# 2/2 [==============================] - 1s 306ms/step - loss: 0.3385 - val_loss: 0.3187
# Epoch 20/50
# 2/2 [==============================] - 1s 309ms/step - loss: 0.3321 - val_loss: 0.3125
# Epoch 21/50
# 2/2 [==============================] - 1s 301ms/step - loss: 0.3257 - val_loss: 0.3064
# Epoch 22/50
# 2/2 [==============================] - 1s 388ms/step - loss: 0.3194 - val_loss: 0.3004
# Epoch 23/50
# 2/2 [==============================] - 1s 374ms/step - loss: 0.3132 - val_loss: 0.2944
# Epoch 24/50
# 2/2 [==============================] - 1s 304ms/step - loss: 0.3070 - val_loss: 0.2886
# Epoch 25/50
# 2/2 [==============================] - 1s 302ms/step - loss: 0.3009 - val_loss: 0.2827
# Epoch 26/50
# 2/2 [==============================] - 1s 309ms/step - loss: 0.2949 - val_loss: 0.2770
# Epoch 27/50
# 2/2 [==============================] - 1s 304ms/step - loss: 0.2889 - val_loss: 0.2713
# Epoch 28/50
# 2/2 [==============================] - 1s 309ms/step - loss: 0.2831 - val_loss: 0.2657
# Epoch 29/50
# 2/2 [==============================] - 1s 306ms/step - loss: 0.2772 - val_loss: 0.2601
# Epoch 30/50
# 2/2 [==============================] - 1s 303ms/step - loss: 0.2715 - val_loss: 0.2546
# Epoch 31/50
# 2/2 [==============================] - 1s 312ms/step - loss: 0.2657 - val_loss: 0.2492
# Epoch 32/50
# 2/2 [==============================] - 1s 305ms/step - loss: 0.2601 - val_loss: 0.2438
# Epoch 33/50
# 2/2 [==============================] - 1s 307ms/step - loss: 0.2545 - val_loss: 0.2385
# Epoch 34/50
# 2/2 [==============================] - 1s 311ms/step - loss: 0.2490 - val_loss: 0.2332
# Epoch 35/50
# 2/2 [==============================] - 1s 307ms/step - loss: 0.2435 - val_loss: 0.2280
# Epoch 36/50
# 2/2 [==============================] - 1s 306ms/step - loss: 0.2381 - val_loss: 0.2228
# Epoch 37/50
# 2/2 [==============================] - 1s 301ms/step - loss: 0.2327 - val_loss: 0.2177
# Epoch 38/50
# 2/2 [==============================] - 1s 308ms/step - loss: 0.2273 - val_loss: 0.2126
# Epoch 39/50
# 2/2 [==============================] - 1s 302ms/step - loss: 0.2219 - val_loss: 0.2075
# Epoch 40/50
# 2/2 [==============================] - 1s 305ms/step - loss: 0.2166 - val_loss: 0.2024
# Epoch 41/50
# 2/2 [==============================] - 1s 335ms/step - loss: 0.2113 - val_loss: 0.1974
# Epoch 42/50
# 2/2 [==============================] - 1s 307ms/step - loss: 0.2060 - val_loss: 0.1924
# Epoch 43/50
# 2/2 [==============================] - 1s 309ms/step - loss: 0.2008 - val_loss: 0.1875
# Epoch 44/50
# 2/2 [==============================] - 1s 312ms/step - loss: 0.1957 - val_loss: 0.1826
# Epoch 45/50
# 2/2 [==============================] - 1s 308ms/step - loss: 0.1906 - val_loss: 0.1778
# Epoch 46/50
# 2/2 [==============================] - 1s 302ms/step - loss: 0.1855 - val_loss: 0.1730
# Epoch 47/50
# 2/2 [==============================] - 1s 313ms/step - loss: 0.1804 - val_loss: 0.1682
# Epoch 48/50
# 2/2 [==============================] - 1s 300ms/step - loss: 0.1754 - val_loss: 0.1636
# Epoch 49/50
# 2/2 [==============================] - 1s 308ms/step - loss: 0.1704 - val_loss: 0.1589
# Epoch 50/50
# 2/2 [==============================] - 1s 318ms/step - loss: 0.1655 - val_loss: 0.1543
# (2352, 209) (1212, 209)
# Epoch 1/50
# 5/5 [==============================] - 3s 343ms/step - loss: 0.0048 - val_loss: 0.0040
# Epoch 2/50
# 5/5 [==============================] - 1s 282ms/step - loss: 0.0047 - val_loss: 0.0040
# Epoch 3/50
# 5/5 [==============================] - 2s 313ms/step - loss: 0.0047 - val_loss: 0.0040
# Epoch 4/50
# 5/5 [==============================] - 1s 282ms/step - loss: 0.0047 - val_loss: 0.0040
# Epoch 5/50
# 5/5 [==============================] - 1s 282ms/step - loss: 0.0047 - val_loss: 0.0040
# Epoch 6/50
# 5/5 [==============================] - 1s 279ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 7/50
# 5/5 [==============================] - 1s 278ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 8/50
# 5/5 [==============================] - 1s 284ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 9/50
# 5/5 [==============================] - 1s 282ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 10/50
# 5/5 [==============================] - 2s 333ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 11/50
# 5/5 [==============================] - 1s 286ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 12/50
# 5/5 [==============================] - 1s 283ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 13/50
# 5/5 [==============================] - 1s 281ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 14/50
# 5/5 [==============================] - 1s 280ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 15/50
# 5/5 [==============================] - 1s 283ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 16/50
# 5/5 [==============================] - 1s 281ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 17/50
# 5/5 [==============================] - 1s 292ms/step - loss: 0.0046 - val_loss: 0.0039
# Epoch 18/50
# 5/5 [==============================] - 1s 288ms/step - loss: 0.0046 - val_loss: 0.0039
# Epoch 19/50
# 5/5 [==============================] - 1s 280ms/step - loss: 0.0046 - val_loss: 0.0039
# Epoch 20/50
# 5/5 [==============================] - 1s 280ms/step - loss: 0.0046 - val_loss: 0.0039
# Epoch 21/50
# 5/5 [==============================] - 1s 281ms/step - loss: 0.0046 - val_loss: 0.0039
# Epoch 22/50
# 5/5 [==============================] - 1s 283ms/step - loss: 0.0046 - val_loss: 0.0039
# Epoch 23/50
# 5/5 [==============================] - 1s 280ms/step - loss: 0.0046 - val_loss: 0.0039
# Epoch 24/50
# 5/5 [==============================] - 1s 287ms/step - loss: 0.0046 - val_loss: 0.0039
# Epoch 25/50
# 5/5 [==============================] - 1s 305ms/step - loss: 0.0046 - val_loss: 0.0038
# Epoch 26/50
# 5/5 [==============================] - 1s 293ms/step - loss: 0.0046 - val_loss: 0.0038
# Epoch 27/50
# 5/5 [==============================] - 1s 280ms/step - loss: 0.0046 - val_loss: 0.0038
# Epoch 28/50
# 5/5 [==============================] - 1s 286ms/step - loss: 0.0046 - val_loss: 0.0038
# Epoch 29/50
# 5/5 [==============================] - 1s 281ms/step - loss: 0.0046 - val_loss: 0.0038
# Epoch 30/50
# 5/5 [==============================] - 1s 281ms/step - loss: 0.0046 - val_loss: 0.0038
# Epoch 31/50
# 5/5 [==============================] - 1s 286ms/step - loss: 0.0046 - val_loss: 0.0038
# Epoch 32/50
# 5/5 [==============================] - 2s 312ms/step - loss: 0.0046 - val_loss: 0.0038
# Epoch 33/50
# 5/5 [==============================] - 1s 298ms/step - loss: 0.0046 - val_loss: 0.0038
# Epoch 34/50
# 5/5 [==============================] - 2s 301ms/step - loss: 0.0046 - val_loss: 0.0038
# Epoch 35/50
# 5/5 [==============================] - 1s 282ms/step - loss: 0.0046 - val_loss: 0.0038
# Epoch 36/50
# 5/5 [==============================] - 1s 281ms/step - loss: 0.0046 - val_loss: 0.0038
# Epoch 37/50
# 5/5 [==============================] - 1s 281ms/step - loss: 0.0045 - val_loss: 0.0038
# Epoch 38/50
# 5/5 [==============================] - 1s 290ms/step - loss: 0.0045 - val_loss: 0.0038
# Epoch 39/50
# 5/5 [==============================] - 1s 284ms/step - loss: 0.0045 - val_loss: 0.0038
# Epoch 40/50
# 5/5 [==============================] - 1s 283ms/step - loss: 0.0045 - val_loss: 0.0038
# Epoch 41/50
# 5/5 [==============================] - 1s 283ms/step - loss: 0.0045 - val_loss: 0.0038
# Epoch 42/50
# 5/5 [==============================] - 1s 282ms/step - loss: 0.0045 - val_loss: 0.0038
# Epoch 43/50
# 5/5 [==============================] - 1s 285ms/step - loss: 0.0045 - val_loss: 0.0038
# Epoch 44/50
# 5/5 [==============================] - 1s 280ms/step - loss: 0.0045 - val_loss: 0.0038
# Epoch 45/50
# 5/5 [==============================] - 1s 287ms/step - loss: 0.0045 - val_loss: 0.0038
# Epoch 46/50
# 5/5 [==============================] - 1s 283ms/step - loss: 0.0045 - val_loss: 0.0038
# Epoch 47/50
# 5/5 [==============================] - 2s 311ms/step - loss: 0.0045 - val_loss: 0.0038
# Epoch 48/50
# 5/5 [==============================] - 1s 286ms/step - loss: 0.0045 - val_loss: 0.0038
# Epoch 49/50
# 5/5 [==============================] - 1s 283ms/step - loss: 0.0045 - val_loss: 0.0038
# Epoch 50/50
# 5/5 [==============================] - 1s 283ms/step - loss: 0.0045 - val_loss: 0.0038
# (1246, 209) (702, 209)
# Epoch 1/50
# 3/3 [==============================] - 2s 404ms/step - loss: 0.0643 - val_loss: 0.0553
# Epoch 2/50
# 3/3 [==============================] - 1s 292ms/step - loss: 0.0638 - val_loss: 0.0548
# Epoch 3/50
# 3/3 [==============================] - 1s 299ms/step - loss: 0.0633 - val_loss: 0.0544
# Epoch 4/50
# 3/3 [==============================] - 1s 300ms/step - loss: 0.0629 - val_loss: 0.0540
# Epoch 5/50
# 3/3 [==============================] - 1s 293ms/step - loss: 0.0624 - val_loss: 0.0536
# Epoch 6/50
# 3/3 [==============================] - 1s 296ms/step - loss: 0.0620 - val_loss: 0.0532
# Epoch 7/50
# 3/3 [==============================] - 1s 295ms/step - loss: 0.0615 - val_loss: 0.0528
# Epoch 8/50
# 3/3 [==============================] - 1s 291ms/step - loss: 0.0611 - val_loss: 0.0524
# Epoch 9/50
# 3/3 [==============================] - 1s 299ms/step - loss: 0.0607 - val_loss: 0.0521
# Epoch 10/50
# 3/3 [==============================] - 1s 296ms/step - loss: 0.0603 - val_loss: 0.0517
# Epoch 11/50
# 3/3 [==============================] - 1s 291ms/step - loss: 0.0599 - val_loss: 0.0514
# Epoch 12/50
# 3/3 [==============================] - 1s 309ms/step - loss: 0.0595 - val_loss: 0.0510
# Epoch 13/50
# 3/3 [==============================] - 1s 293ms/step - loss: 0.0591 - val_loss: 0.0507
# Epoch 14/50
# 3/3 [==============================] - 1s 296ms/step - loss: 0
50
# 3/3 [==============================] - 1s 296ms/step - loss: 0.0492 - val_loss: 0.0423
# Epoch 49/50
# 3/3 [==============================] - 1s 292ms/step - loss: 0.0490 - val_loss: 0.0422
# Epoch 50/50
# 3/3 [==============================] - 1s 296ms/step - loss: 0.0488 - val_loss: 0.0420
# (7877, 209) (4032, 209)
# Epoch 1/50
# 16/16 [==============================] - 6s 299ms/step - loss: 0.0039 - val_loss: 0.0038
# Epoch 2/50
# 16/16 [==============================] - 4s 275ms/step - loss: 0.0039 - val_loss: 0.0038
# Epoch 3/50
# 16/16 [==============================] - 4s 273ms/step - loss: 0.0039 - val_loss: 0.0038
# Epoch 4/50
# 16/16 [==============================] - 4s 274ms/step - loss: 0.0039 - val_loss: 0.0038
# Epoch 5/50
# 16/16 [==============================] - 4s 279ms/step - loss: 0.0039 - val_loss: 0.0038
# Epoch 6/50
# 16/16 [==============================] - 4s 274ms/step - loss: 0.0039 - val_loss: 0.0037
# Epoch 7/50
# 16/16 [==============================] - 4s 273ms/step - loss: 0.0039 - val_loss: 0.0037
# Epoch 8/50
# 16/16 [==============================] - 4s 280ms/step - loss: 0.0039 - val_loss: 0.0037
# Epoch 9/50
# 16/16 [==============================] - 4s 277ms/step - loss: 0.0038 - val_loss: 0.0037
# Epoch 10/50
# 16/16 [==============================] - 4s 270ms/step - loss: 0.0038 - val_loss: 0.0037
# Epoch 11/50
# 16/16 [==============================] - 4s 275ms/step - loss: 0.0038 - val_loss: 0.0037
# Epoch 12/50
# 16/16 [==============================] - 4s 275ms/step - loss: 0.0038 - val_loss: 0.0037
# Epoch 13/50
# 16/16 [==============================] - 4s 276ms/step - loss: 0.0038 - val_loss: 0.0037
# Epoch 14/50
# 16/16 [==============================] - 4s 278ms/step - loss: 0.0038 - val_loss: 0.0037
# Epoch 15/50
# 16/16 [==============================] - 4s 281ms/step - loss: 0.0038 - val_loss: 0.0037
# Epoch 16/50
# 16/16 [==============================] - 4s 280ms/step - loss: 0.0038 - val_loss: 0.0037
# Epoch 17/50
# 16/16 [==============================] - 4s 273ms/step - loss: 0.0038 - val_loss: 0.0037
# Epoch 18/50
# 16/16 [==============================] - 4s 276ms/step - loss: 0.0038 - val_loss: 0.0037
# Epoch 19/50
# 16/16 [==============================] - 5s 285ms/step - loss: 0.0038 - val_loss: 0.0037
# Epoch 20/50
# 16/16 [==============================] - 4s 278ms/step - loss: 0.0038 - val_loss: 0.0036
# Epoch 21/50
# 16/16 [==============================] - 4s 272ms/step - loss: 0.0038 - val_loss: 0.0036
# Epoch 22/50
# 16/16 [==============================] - 4s 273ms/step - loss: 0.0038 - val_loss: 0.0036
# Epoch 23/50
# 16/16 [==============================] - 5s 285ms/step - loss: 0.0038 - val_loss: 0.0036
# Epoch 24/50
# 16/16 [==============================] - 4s 271ms/step - loss: 0.0038 - val_loss: 0.0036
# Epoch 25/50
# 16/16 [==============================] - 4s 272ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 26/50
# 16/16 [==============================] - 4s 282ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 27/50
# 16/16 [==============================] - 4s 280ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 28/50
# 16/16 [==============================] - 4s 272ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 29/50
# 16/16 [==============================] - 4s 273ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 30/50
# 16/16 [==============================] - 5s 287ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 31/50
# 16/16 [==============================] - 4s 276ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 32/50
# 16/16 [==============================] - 4s 272ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 33/50
# 16/16 [==============================] - 5s 286ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 34/50
# 16/16 [==============================] - 4s 275ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 35/50
# 16/16 [==============================] - 4s 272ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 36/50
# 16/16 [==============================] - 4s 273ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 37/50
# 16/16 [==============================] - 5s 282ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 38/50
# 16/16 [==============================] - 4s 274ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 39/50
# 16/16 [==============================] - 4s 271ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 40/50
# 16/16 [==============================] - 4s 272ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 41/50
# 16/16 [==============================] - 5s 289ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 42/50
# 16/16 [==============================] - 4s 273ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 43/50
# 16/16 [==============================] - 4s 273ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 44/50
# 16/16 [==============================] - 5s 284ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 45/50
# 16/16 [==============================] - 4s 273ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 46/50
# 16/16 [==============================] - 4s 274ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 47/50
# 16/16 [==============================] - 4s 275ms/step - loss: 0.0037 - val_loss: 0.0035
# Epoch 48/50
# 16/16 [==============================] - 4s 278ms/step - loss: 0.0037 - val_loss: 0.0035
# Epoch 49/50
# 16/16 [==============================] - 4s 274ms/step - loss: 0.0037 - val_loss: 0.0035
# Epoch 50/50
# 16/16 [==============================] - 4s 276ms/step - loss: 0.0037 - val_loss: 0.0035

# %%
for i in range(len(models_by_cluster)):
    models_by_cluster[i].save(f'model_cluster{i}.keras')
