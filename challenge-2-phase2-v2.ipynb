# %%
# Fix randomness and hide warnings
seed = 42

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd()+'/configs/'

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

import random
random.seed(seed)

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
print(tf.__version__)
# Out:
# 2.14.0

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', size=16)
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
import numpy as np

# Load the numpy array from the file
data = np.load('training/training_data.npy')
valid_periods = np.load('training/valid_periods.npy')
categories = np.load('training/categories.npy')
data.shape
# Out:
# (48000, 2776)

# %%
new_data = []

for idx in range(len(data)):  # Use range instead of len
    start_idx = valid_periods[idx][0]

    while start_idx + 209 <= valid_periods[idx][1]:  # Adjust the condition
        # subarray of length 209 to be added to new data
        interval = data[idx, start_idx:start_idx + 209]
        new_data.append(interval)

        start_idx += 209

# Convert the list to a numpy array
newnew_data = np.array(new_data)

# Check the shape of the new data
print(data.shape)
# Out:
# (48000, 2776)

# %%
# Calculate the number of valid points for each function
num_valid_points = valid_periods[:, 1] - valid_periods[:, 0] + 1

# Filter out functions with less than 210 valid points
filtered_data = data[num_valid_points >= 210]

# Check the shape of the filtered data
print(filtered_data.shape)
data = filtered_data
# Out:
# (21970, 2776)

# %%
# Convert training_data and categories to DataFrame
data_df = pd.DataFrame(data, columns=[f'Timestep_{i+1}' for i in range(data.shape[1])])
categories_df = pd.DataFrame(categories, columns=['Category'])

# Concatenate DataFrames along the columns
df = pd.concat([data_df, categories_df], axis=1)

# Display the resulting DataFrame
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48000 entries, 0 to 47999
# Columns: 2777 entries, Timestep_1 to Category
# dtypes: float64(2776), object(1)
# memory usage: 1017.0+ MB
#          Timestep_1    Timestep_2    Timestep_3    Timestep_4    Timestep_5  \
# count  21970.000000  21970.000000  21970.000000  21970.000000  21970.000000
# mean       0.000008      0.000008      0.000008      0.000008      0.000008
# std        0.001237      0.001201      0.001154      0.001124      0.001119
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        0.183319      0.178061      0.171051      0.166542      0.165793
#
#          Timestep_6    Timestep_7    Timestep_8    Timestep_9   Timestep_10  \
# count  21970.000000  21970.000000  21970.000000  21970.000000  21970.000000
# mean       0.000007      0.000007      0.000007      0.000007      0.000007
# std        0.001107      0.001102      0.001095      0.001095      0.001083
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        0.164041      0.163324      0.162288      0.162288      0.160536
#
#        ...  Timestep_2767  Timestep_2768  Timestep_2769  Timestep_2770  \
# count  ...   21970.000000   21970.000000   21970.000000   21970.000000
# mean   ...       0.595932       0.604305       0.613837       0.615924
# std    ...       0.282408       0.283490       0.283004       0.281195
# min    ...       0.000000       0.000000       0.000000       0.000000
# 25%    ...       0.367089       0.374737       0.386136       0.391605
# 50%    ...       0.662281       0.676649       0.689696       0.691024
# 75%    ...       0.838710       0.849405       0.857273       0.859330
# max    ...       1.000000       1.000000       1.000000       1.000000
#
#        Timestep_2771  Timestep_2772  Timestep_2773  Timestep_2774  \
# count   21970.000000   21970.000000   21970.000000   21970.000000
# mean        0.612213       0.612401       0.613662       0.620510
# std         0.283854       0.286105       0.286328       0.287996
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.386792       0.385368       0.387692       0.389710
# 50%         0.689320       0.689699       0.694281       0.706620
# 75%         0.857497       0.860458       0.860899       0.868720
# max         1.000000       1.000000       1.000000       1.000000
#
#        Timestep_2775  Timestep_2776
# count   21970.000000   21970.000000
# mean        0.627669       0.627484
# std         0.288089       0.289991
# min         0.000000       0.000000
# 25%         0.400000       0.401287
# 50%         0.715241       0.714286
# 75%         0.877148       0.877193
# max         1.000000       1.000000
#
# [8 rows x 2776 columns]

# %%
# Inspect activities timestamps
plt.figure(figsize=(17,5))
sns.countplot(x = 'Category', data = df, order = sorted(df['Category'].unique()))
plt.title('Activity Timestamps')
plt.show()

# %%
# Plot some samples
for category in "ABCDEF":
    to_be_inspected = 5

    plt.figure(figsize=(17, 3))  # Adjust the figure size as needed
    plt.suptitle(f'Category {category} - Time Series Samples')

    for idx in range(len(data)):
        if to_be_inspected == 0:
            break

        if categories[idx] != category:
            continue

        plt.subplot(1, 5, 6 - to_be_inspected)  # 1 row, 5 columns, and the current plot position
        plt.plot(data[idx])
        plt.title(f'Sample {idx + 1}')
        plt.xlabel('Time Steps')
        plt.ylabel('Feature Value')

        to_be_inspected -= 1

    plt.tight_layout()  # Adjust layout for better appearance
    plt.show()

# %%
# Shuffle the datasets in unison
perm = np.random.permutation(data.shape[0])
data_shuffled = data[perm]
valid_periods_shuffled = valid_periods[perm]

K = 10000
# Split into training and validation sets
validation_data = data_shuffled[:K]
validation_periods = valid_periods_shuffled[:K]

training_data = data_shuffled[K:]
training_periods = valid_periods_shuffled[K:]

# %%
def apply_valid_periods(data, valid_periods):
    """
    Modify each function in 'data' based on the corresponding 'valid_periods'.

    Parameters:
    data (numpy.ndarray): Array of functions, shape (n_samples, n_features).
    valid_periods (numpy.ndarray): Array of valid periods, shape (n_samples, 2).

    Returns:
    numpy.ndarray: Modified data array.
    """
    modified_data = np.zeros_like(data)
    n_samples, n_features = data.shape

    for i in range(n_samples):
        left, right = valid_periods[i]
        # Assuming 'left' and 'right' are indices in the range [0, n_features-1]
        # Adjust them if they are in a different format
        modified_data[i, left:right+1] = data[i, left:right+1]

    return modified_data

# Apply the function to your datasets
modified_training_data = apply_valid_periods(training_data, training_periods)
modified_validation_data = apply_valid_periods(validation_data, validation_periods)
#modified_test_data = apply_valid_periods(test_data, test_periods)

# %%
def extract_fixed_intervals(data, interval_length=209):
    """
    For each function in 'data', extract a random interval of 'interval_length'.
    If a function has fewer than 'interval_length' points, pad the rest with zeros.

    Parameters:
    data (numpy.ndarray): Array of functions, shape (n_samples, n_features).
    interval_length (int): Length of the interval to extract.

    Returns:
    numpy.ndarray: Data array with fixed-size intervals extracted.
    """
    n_samples, n_features = data.shape
    modified_data = np.zeros((n_samples, interval_length))

    for i in range(n_samples):
        nonzero_indices = np.nonzero(data[i])[0]

        # Check if there are enough nonzero points
        if nonzero_indices.size >= interval_length:
            start_idx = np.random.choice(nonzero_indices[:-interval_length+1])
            end_idx = start_idx + interval_length
            modified_data[i] = data[i, start_idx:end_idx]
        else:
            # If not enough points, just copy what is available
            modified_data[i, :nonzero_indices.size] = data[i, nonzero_indices]

    return modified_data

# Apply the function to your datasets
final_training_data = extract_fixed_intervals(modified_training_data)
final_validation_data = extract_fixed_intervals(modified_validation_data)
#final_test_data = extract_fixed_intervals(modified_test_data)

# %%
final_training_data.shape
# Out:
# (11970, 209)

# %%
num_predictions = 18
X_train.shape
# Out:
# (11970, 191)

# %% [markdown]
# ### With a masking layer

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Dropout, Attention, LayerNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers.legacy import Adam
from tensorflow.keras.callbacks import EarlyStopping, TerminateOnNaN, LearningRateScheduler, ReduceLROnPlateau

num_predictions = 18

# Assuming final_training_data and final_validation_data are your datasets
# Reshape data for Transformer input
X_train = final_training_data[:, :-num_predictions]
y_train = final_training_data[:, -num_predictions:]

X_val = final_validation_data[:, :-num_predictions]
y_val = final_validation_data[:, -num_predictions:]

# Hyperparameters
d_model = 128  # Dimensionality of the model
num_heads = 64   # Number of attention heads
ff_dim = 128    # Dimensionality of the feed-forward layer

# Input layer
input_layer = Input(shape=(X_train.shape[1],))
masking_layer = tfkl.Masking(mask_value=0.0)(input_layer)

# Transformer Encoder
x = Dense(d_model, activation='relu')(masking_layer)
x = Dropout(0.1)(x)

x = Dense(ff_dim, activation='relu')(x)
x = Dropout(0.1)(x)

# Add layer normalization
x = LayerNormalization()(x)

# Output layer
output_layer = Dense(num_predictions)(x)

# Create and compile the model
model = Model(inputs=input_layer, outputs=output_layer)
optimizer = Adam(lr=0.01)  # Adjust the initial learning rate
model.compile(optimizer=optimizer, loss='mse')

# Callbacks
early_stopping = EarlyStopping(monitor='val_mse', patience=10, restore_best_weights=True)
terminate_on_nan = TerminateOnNaN()
reduce_on_plateau = ReduceLROnPlateau(monitor='val_mse', mode='min', patience=5, factor=0.5, min_lr=1e-5)

# Learning rate scheduler
def lr_scheduler(epoch, lr):
    if epoch < 100:
        return lr
    else:
        return lr * tf.math.exp(-0.00002)

learning_rate_scheduler = LearningRateScheduler(lr_scheduler)

# Train the model
history = model.fit(
    X_train, 
    y_train, 
    validation_data=(X_val, y_val), 
    epochs=300, 
    batch_size=64,
    callbacks=[early_stopping, terminate_on_nan, learning_rate_scheduler]
).history
# Out:
# Epoch 1/300
# 188/188 [==============================] - 4s 16ms/step - loss: 0.1241 - val_loss: 0.0296 - lr: 0.0100
# Epoch 2/300
# 188/188 [==============================] - 3s 13ms/step - loss: 0.0304 - val_loss: 0.0288 - lr: 0.0100
# Epoch 3/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0249 - val_loss: 0.0207 - lr: 0.0100
# Epoch 4/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0223 - val_loss: 0.0343 - lr: 0.0100
# Epoch 5/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0225 - val_loss: 0.0205 - lr: 0.0100
# Epoch 6/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0199 - val_loss: 0.0204 - lr: 0.0100
# Epoch 7/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0192 - val_loss: 0.0195 - lr: 0.0100
# Epoch 8/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0181 - val_loss: 0.0164 - lr: 0.0100
# Epoch 9/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0166 - val_loss: 0.0151 - lr: 0.0100
# Epoch 10/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0158 - val_loss: 0.0166 - lr: 0.0100
# Epoch 11/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0154 - val_loss: 0.0155 - lr: 0.0100
# Epoch 12/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0142 - val_loss: 0.0142 - lr: 0.0100
# Epoch 13/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0137 - val_loss: 0.0158 - lr: 0.0100
# Epoch 14/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0135 - val_loss: 0.0157 - lr: 0.0100
# Epoch 15/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0136 - val_loss: 0.0125 - lr: 0.0100
# Epoch 16/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0132 - val_loss: 0.0122 - lr: 0.0100
# Epoch 17/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0130 - val_loss: 0.0125 - lr: 0.0100
# Epoch 18/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0129 - val_loss: 0.0126 - lr: 0.0100
# Epoch 19/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0128 - val_loss: 0.0130 - lr: 0.0100
# Epoch 20/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0129 - val_loss: 0.0176 - lr: 0.0100
# Epoch 21/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0132 - val_loss: 0.0156 - lr: 0.0100
# Epoch 22/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0132 - val_loss: 0.0123 - lr: 0.0100
# Epoch 23/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0127 - val_loss: 0.0121 - lr: 0.0100
# Epoch 24/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0130 - val_loss: 0.0198 - lr: 0.0100
# Epoch 25/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0132 - val_loss: 0.0122 - lr: 0.0100
# Epoch 26/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0129 - val_loss: 0.0123 - lr: 0.0100
# Epoch 27/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0129 - val_loss: 0.0123 - lr: 0.0100
# Epoch 28/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0129 - val_loss: 0.0132 - lr: 0.0100
# Epoch 29/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0135 - val_loss: 0.0129 - lr: 0.0100
# Epoch 30/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0132 - val_loss: 0.0124 - lr: 0.0100
# Epoch 31/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0131 - val_loss: 0.0150 - lr: 0.0100
# Epoch 32/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0130 - val_loss: 0.0127 - lr: 0.0100
# Epoch 33/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0133 - val_loss: 0.0127 - lr: 0.0100
# Epoch 34/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0131 - val_loss: 0.0138 - lr: 0.0100
# Epoch 35/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0132 - val_loss: 0.0142 - lr: 0.0100
# Epoch 36/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0134 - val_loss: 0.0128 - lr: 0.0100
# Epoch 37/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0132 - val_loss: 0.0134 - lr: 0.0100
# Epoch 38/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0133 - val_loss: 0.0149 - lr: 0.0100
# Epoch 39/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0135 - val_loss: 0.0133 - lr: 0.0100
# Epoch 40/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0135 - val_loss: 0.0199 - lr: 0.0100
# Epoch 41/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0137 - val_loss: 0.0134 - lr: 0.0100
# Epoch 42/300
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0135 - val_loss: 0.0135 - lr: 0.0100
# Epoch 43/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0134 - val_loss: 0.0128 - lr: 0.0100
# Epoch 44/300
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0135 - val_loss: 0.0127 - lr: 0.0100
# Epoch 45/300
# 188/188 [==============================] - 3s 13ms/step - loss: 0.0134 - val_loss: 0.0128 - lr: 0.0100
# Epoch 46/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0137 - val_loss: 0.0144 - lr: 0.0100
# Epoch 47/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0137 - val_loss: 0.0147 - lr: 0.0100
# Epoch 48/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0140 - val_loss: 0.0151 - lr: 0.0100
# Epoch 49/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0141 - val_loss: 0.0130 - lr: 0.0100
# Epoch 50/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0138 - val_loss: 0.0131 - lr: 0.0100
# Epoch 51/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0136 - val_loss: 0.0139 - lr: 0.0100
# Epoch 52/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0139 - val_loss: 0.0132 - lr: 0.0100
# Epoch 53/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0136 - val_loss: 0.0131 - lr: 0.0100
# Epoch 54/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0139 - val_loss: 0.0136 - lr: 0.0100
# Epoch 55/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0139 - val_loss: 0.0133 - lr: 0.0100
# Epoch 56/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0137 - val_loss: 0.0162 - lr: 0.0100
# Epoch 57/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0144 - val_loss: 0.0159 - lr: 0.0100
# Epoch 58/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0138 - val_loss: 0.0143 - lr: 0.0100
# Epoch 59/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0138 - val_loss: 0.0142 - lr: 0.0100
# Epoch 60/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0139 - val_loss: 0.0156 - lr: 0.0100
# Epoch 61/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0137 - val_loss: 0.0144 - lr: 0.0100
# Epoch 62/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0138 - val_loss: 0.0136 - lr: 0.0100
# Epoch 63/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0139 - val_loss: 0.0156 - lr: 0.0100
# Epoch 64/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0138 - val_loss: 0.0142 - lr: 0.0100
# Epoch 65/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0139 - val_loss: 0.0264 - lr: 0.0100
# Epoch 66/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0142 - val_loss: 0.0132 - lr: 0.0100
# Epoch 67/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0135 - val_loss: 0.0129 - lr: 0.0100
# Epoch 68/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0134 - val_loss: 0.0194 - lr: 0.0100
# Epoch 69/300
# 188/188 [==============================] - 3s 13ms/step - loss: 0.0143 - val_loss: 0.0144 - lr: 0.0100
# Epoch 70/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0138 - val_loss: 0.0135 - lr: 0.0100
# Epoch 71/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0137 - val_loss: 0.0135 - lr: 0.0100
# Epoch 72/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0136 - val_loss: 0.0133 - lr: 0.0100
# Epoch 73/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0137 - val_loss: 0.0142 - lr: 0.0100
# Epoch 74/300
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0138 - val_loss: 0.0131 - lr: 0.0100
# Epoch 75/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0139 - val_loss: 0.0147 - lr: 0.0100
# Epoch 76/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0139 - val_loss: 0.0146 - lr: 0.0100
# Epoch 77/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0138 - val_loss: 0.0132 - lr: 0.0100
# Epoch 78/300
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0139 - val_loss: 0.0131 - lr: 0.0100
# Epoch 79/300
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0138 - val_loss: 0.0136 - lr: 0.0100
# Epoch 80/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0137 - val_loss: 0.0215 - lr: 0.0100
# Epoch 81/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0148 - val_loss: 0.0139 - lr: 0.0100
# Epoch 82/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0139 - val_loss: 0.0134 - lr: 0.0100
# Epoch 83/300
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0137 - val_loss: 0.0130 - lr: 0.0100
# Epoch 84/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0137 - val_loss: 0.0139 - lr: 0.0100
# Epoch 85/300
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0140 - val_loss: 0.0134 - lr: 0.0100
# Epoch 86/300
# 188/188 [==============================] - 3s 13ms/step - loss: 0.0137 - val_loss: 0.0139 - lr: 0.0100
# Epoch 87/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0136 - val_loss: 0.0131 - lr: 0.0100
# Epoch 88/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0137 - val_loss: 0.0134 - lr: 0.0100
# Epoch 89/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0138 - val_loss: 0.0162 - lr: 0.0100
# Epoch 90/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0138 - val_loss: 0.0135 - lr: 0.0100
# Epoch 91/300
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0137 - val_loss: 0.0153 - lr: 0.0100
# Epoch 92/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0136 - val_loss: 0.0206 - lr: 0.0100
# Epoch 93/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0143 - val_loss: 0.0134 - lr: 0.0100
# Epoch 94/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0135 - val_loss: 0.0137 - lr: 0.0100
# Epoch 95/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0136 - val_loss: 0.0133 - lr: 0.0100
# Epoch 96/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0136 - val_loss: 0.0131 - lr: 0.0100
# Epoch 97/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0136 - val_loss: 0.0140 - lr: 0.0100
# Epoch 98/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0137 - val_loss: 0.0133 - lr: 0.0100
# Epoch 99/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0135 - val_loss: 0.0145 - lr: 0.0100
# Epoch 100/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0137 - val_loss: 0.0156 - lr: 0.0100
# Epoch 101/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0139 - val_loss: 0.0133 - lr: 0.0100
# Epoch 102/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0136 - val_loss: 0.0142 - lr: 0.0100
# Epoch 103/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0137 - val_loss: 0.0149 - lr: 0.0100
# Epoch 104/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0136 - val_loss: 0.0136 - lr: 0.0100
# Epoch 105/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0135 - val_loss: 0.0139 - lr: 0.0100
# Epoch 106/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0137 - val_loss: 0.0137 - lr: 0.0100
# Epoch 107/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0136 - val_loss: 0.0157 - lr: 0.0100
# Epoch 108/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0138 - val_loss: 0.0132 - lr: 0.0100
# Epoch 109/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0137 - val_loss: 0.0141 - lr: 0.0100
# Epoch 110/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0137 - val_loss: 0.0134 - lr: 0.0100
# Epoch 111/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0136 - val_loss: 0.0152 - lr: 0.0100
# Epoch 112/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0138 - val_loss: 0.0135 - lr: 0.0100
# Epoch 113/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0136 - val_loss: 0.0139 - lr: 0.0100
# Epoch 114/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0138 - val_loss: 0.0138 - lr: 0.0100
# Epoch 115/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0137 - val_loss: 0.0129 - lr: 0.0100
# Epoch 116/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0136 - val_loss: 0.0133 - lr: 0.0100
# Epoch 117/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0135 - val_loss: 0.0130 - lr: 0.0100
# Epoch 118/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0136 - val_loss: 0.0127 - lr: 0.0100
# Epoch 119/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0136 - val_loss: 0.0138 - lr: 0.0100
# Epoch 120/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0136 - val_loss: 0.0132 - lr: 0.0100
# Epoch 121/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0133 - val_loss: 0.0137 - lr: 0.0100
# Epoch 122/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0134 - val_loss: 0.0158 - lr: 0.0100
# Epoch 123/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0139 - val_loss: 0.0134 - lr: 0.0100
# Epoch 124/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0133 - val_loss: 0.0130 - lr: 0.0100
# Epoch 125/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0133 - val_loss: 0.0129 - lr: 0.0100
# Epoch 126/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0133 - val_loss: 0.0143 - lr: 0.0100
# Epoch 127/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0133 - val_loss: 0.0133 - lr: 0.0100
# Epoch 128/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0132 - val_loss: 0.0127 - lr: 0.0100
# Epoch 129/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0134 - val_loss: 0.0131 - lr: 0.0100
# Epoch 130/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0132 - val_loss: 0.0145 - lr: 0.0100
# Epoch 131/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0133 - val_loss: 0.0130 - lr: 0.0100
# Epoch 132/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0131 - val_loss: 0.0130 - lr: 0.0100
# Epoch 133/300
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0133 - val_loss: 0.0134 - lr: 0.0100
# Epoch 134/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0132 - val_loss: 0.0187 - lr: 0.0100
# Epoch 135/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0144 - val_loss: 0.0132 - lr: 0.0100
# Epoch 136/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0133 - val_loss: 0.0140 - lr: 0.0100
# Epoch 137/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0134 - val_loss: 0.0127 - lr: 0.0100
# Epoch 138/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0131 - val_loss: 0.0129 - lr: 0.0100
# Epoch 139/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0132 - val_loss: 0.0129 - lr: 0.0100
# Epoch 140/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0132 - val_loss: 0.0150 - lr: 0.0100
# Epoch 141/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0133 - val_loss: 0.0130 - lr: 0.0100
# Epoch 142/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0133 - val_loss: 0.0135 - lr: 0.0100
# Epoch 143/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0135 - val_loss: 0.0136 - lr: 0.0100
# Epoch 144/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0132 - val_loss: 0.0126 - lr: 0.0100
# Epoch 145/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0132 - val_loss: 0.0133 - lr: 0.0100
# Epoch 146/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0134 - val_loss: 0.0126 - lr: 0.0100
# Epoch 147/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0133 - val_loss: 0.0128 - lr: 0.0100
# Epoch 148/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0132 - val_loss: 0.0130 - lr: 0.0100
# Epoch 149/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0134 - val_loss: 0.0127 - lr: 0.0100
# Epoch 150/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0134 - val_loss: 0.0130 - lr: 0.0100
# Epoch 151/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0134 - val_loss: 0.0130 - lr: 0.0100
# Epoch 152/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0135 - val_loss: 0.0136 - lr: 0.0100
# Epoch 153/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0134 - val_loss: 0.0142 - lr: 0.0100
# Epoch 154/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0134 - val_loss: 0.0137 - lr: 0.0100
# Epoch 155/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0135 - val_loss: 0.0130 - lr: 0.0100
# Epoch 156/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0132 - val_loss: 0.0138 - lr: 0.0100
# Epoch 157/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0137 - val_loss: 0.0133 - lr: 0.0100
# Epoch 158/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0134 - val_loss: 0.0129 - lr: 0.0100
# Epoch 159/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0135 - val_loss: 0.0156 - lr: 0.0100
# Epoch 160/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0137 - val_loss: 0.0130 - lr: 0.0100
# Epoch 161/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0133 - val_loss: 0.0127 - lr: 0.0100
# Epoch 162/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0133 - val_loss: 0.0146 - lr: 0.0100
# Epoch 163/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0133 - val_loss: 0.0140 - lr: 0.0100
# Epoch 164/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0132 - val_loss: 0.0136 - lr: 0.0100
# Epoch 165/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0133 - val_loss: 0.0127 - lr: 0.0100
# Epoch 166/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0134 - val_loss: 0.0127 - lr: 0.0100
# Epoch 167/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0136 - val_loss: 0.0129 - lr: 0.0100
# Epoch 168/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0134 - val_loss: 0.0142 - lr: 0.0100
# Epoch 169/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0134 - val_loss: 0.0137 - lr: 0.0100
# Epoch 170/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0133 - val_loss: 0.0145 - lr: 0.0100
# Epoch 171/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0135 - val_loss: 0.0137 - lr: 0.0100
# Epoch 172/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0135 - val_loss: 0.0125 - lr: 0.0100
# Epoch 173/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0134 - val_loss: 0.0131 - lr: 0.0100
# Epoch 174/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0134 - val_loss: 0.0135 - lr: 0.0100
# Epoch 175/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0134 - val_loss: 0.0126 - lr: 0.0100
# Epoch 176/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0135 - val_loss: 0.0129 - lr: 0.0100
# Epoch 177/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0133 - val_loss: 0.0131 - lr: 0.0100
# Epoch 178/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0135 - val_loss: 0.0125 - lr: 0.0100
# Epoch 179/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0134 - val_loss: 0.0128 - lr: 0.0100
# Epoch 180/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0134 - val_loss: 0.0125 - lr: 0.0100
# Epoch 181/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0133 - val_loss: 0.0131 - lr: 0.0100
# Epoch 182/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0133 - val_loss: 0.0131 - lr: 0.0100
# Epoch 183/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0133 - val_loss: 0.0125 - lr: 0.0100
# Epoch 184/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0133 - val_loss: 0.0128 - lr: 0.0100
# Epoch 185/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0133 - val_loss: 0.0136 - lr: 0.0100
# Epoch 186/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0133 - val_loss: 0.0140 - lr: 0.0100
# Epoch 187/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0134 - val_loss: 0.0136 - lr: 0.0100
# Epoch 188/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0132 - val_loss: 0.0129 - lr: 0.0100
# Epoch 189/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0133 - val_loss: 0.0131 - lr: 0.0100
# Epoch 190/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0134 - val_loss: 0.0127 - lr: 0.0100
# Epoch 191/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0132 - val_loss: 0.0132 - lr: 0.0100
# Epoch 192/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0136 - val_loss: 0.0124 - lr: 0.0100
# Epoch 193/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0132 - val_loss: 0.0127 - lr: 0.0100
# Epoch 194/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0133 - val_loss: 0.0184 - lr: 0.0100
# Epoch 195/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0134 - val_loss: 0.0129 - lr: 0.0100
# Epoch 196/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0132 - val_loss: 0.0142 - lr: 0.0100
# Epoch 197/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0134 - val_loss: 0.0132 - lr: 0.0100
# Epoch 198/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0132 - val_loss: 0.0126 - lr: 0.0100
# Epoch 199/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0132 - val_loss: 0.0128 - lr: 0.0100
# Epoch 200/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0134 - val_loss: 0.0169 - lr: 0.0100
# Epoch 201/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0135 - val_loss: 0.0164 - lr: 0.0100
# Epoch 202/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0136 - val_loss: 0.0133 - lr: 0.0100
# Epoch 203/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0133 - val_loss: 0.0151 - lr: 0.0100
# Epoch 204/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0135 - val_loss: 0.0126 - lr: 0.0100
# Epoch 205/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0133 - val_loss: 0.0132 - lr: 0.0100
# Epoch 206/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0134 - val_loss: 0.0131 - lr: 0.0100
# Epoch 207/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0134 - val_loss: 0.0127 - lr: 0.0100
# Epoch 208/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0132 - val_loss: 0.0125 - lr: 0.0100
# Epoch 209/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0131 - val_loss: 0.0127 - lr: 0.0100
# Epoch 210/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0134 - val_loss: 0.0128 - lr: 0.0100
# Epoch 211/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0133 - val_loss: 0.0124 - lr: 0.0100
# Epoch 212/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0134 - val_loss: 0.0126 - lr: 0.0100
# Epoch 213/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0131 - val_loss: 0.0132 - lr: 0.0100
# Epoch 214/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0134 - val_loss: 0.0138 - lr: 0.0100
# Epoch 215/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0131 - val_loss: 0.0130 - lr: 0.0100
# Epoch 216/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0133 - val_loss: 0.0128 - lr: 0.0100
# Epoch 217/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0133 - val_loss: 0.0131 - lr: 0.0100
# Epoch 218/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0132 - val_loss: 0.0124 - lr: 0.0100
# Epoch 219/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0132 - val_loss: 0.0125 - lr: 0.0100
# Epoch 220/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0134 - val_loss: 0.0126 - lr: 0.0100
# Epoch 221/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0133 - val_loss: 0.0149 - lr: 0.0100
# Epoch 222/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0133 - val_loss: 0.0128 - lr: 0.0100
# Epoch 223/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0133 - val_loss: 0.0126 - lr: 0.0100
# Epoch 224/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0132 - val_loss: 0.0131 - lr: 0.0100
# Epoch 225/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0132 - val_loss: 0.0129 - lr: 0.0100
# Epoch 226/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0134 - val_loss: 0.0137 - lr: 0.0100
# Epoch 227/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0132 - val_loss: 0.0127 - lr: 0.0100
# Epoch 228/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0132 - val_loss: 0.0128 - lr: 0.0100
# Epoch 229/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0131 - val_loss: 0.0130 - lr: 0.0100
# Epoch 230/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0131 - val_loss: 0.0141 - lr: 0.0100
# Epoch 231/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0134 - val_loss: 0.0134 - lr: 0.0100
# Epoch 232/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0132 - val_loss: 0.0129 - lr: 0.0100
# Epoch 233/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0131 - val_loss: 0.0139 - lr: 0.0100
# Epoch 234/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0132 - val_loss: 0.0134 - lr: 0.0100
# Epoch 235/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0131 - val_loss: 0.0126 - lr: 0.0100
# Epoch 236/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0131 - val_loss: 0.0128 - lr: 0.0100
# Epoch 237/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0131 - val_loss: 0.0131 - lr: 0.0100
# Epoch 238/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0133 - val_loss: 0.0126 - lr: 0.0100
# Epoch 239/300
# 188/188 [==============================] - 3s 16ms/step - loss: 0.0132 - val_loss: 0.0127 - lr: 0.0100
# Epoch 240/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0131 - val_loss: 0.0132 - lr: 0.0100
# Epoch 241/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0131 - val_loss: 0.0127 - lr: 0.0100
# Epoch 242/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0133 - val_loss: 0.0131 - lr: 0.0100
# Epoch 243/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0131 - val_loss: 0.0147 - lr: 0.0100
# Epoch 244/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0135 - val_loss: 0.0174 - lr: 0.0100
# Epoch 245/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0138 - val_loss: 0.0124 - lr: 0.0100
# Epoch 246/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0131 - val_loss: 0.0135 - lr: 0.0100
# Epoch 247/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0132 - val_loss: 0.0130 - lr: 0.0100
# Epoch 248/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0130 - val_loss: 0.0137 - lr: 0.0100
# Epoch 249/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0132 - val_loss: 0.0131 - lr: 0.0100
# Epoch 250/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0129 - val_loss: 0.0145 - lr: 0.0100
# Epoch 251/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0129 - val_loss: 0.0124 - lr: 0.0100
# Epoch 252/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0129 - val_loss: 0.0124 - lr: 0.0100
# Epoch 253/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0128 - val_loss: 0.0147 - lr: 0.0100
# Epoch 254/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0132 - val_loss: 0.0145 - lr: 0.0100
# Epoch 255/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0130 - val_loss: 0.0127 - lr: 0.0100
# Epoch 256/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0129 - val_loss: 0.0139 - lr: 0.0100
# Epoch 257/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0129 - val_loss: 0.0197 - lr: 0.0100
# Epoch 258/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0134 - val_loss: 0.0128 - lr: 0.0100
# Epoch 259/300
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0130 - val_loss: 0.0164 - lr: 0.0100
# Epoch 260/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0132 - val_loss: 0.0146 - lr: 0.0100
# Epoch 261/300
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0130 - val_loss: 0.0124 - lr: 0.0100
# Epoch 262/300
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0129 - val_loss: 0.0133 - lr: 0.0100
# Epoch 263/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0130 - val_loss: 0.0130 - lr: 0.0100
# Epoch 264/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0130 - val_loss: 0.0154 - lr: 0.0100
# Epoch 265/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0130 - val_loss: 0.0135 - lr: 0.0100
# Epoch 266/300
# 188/188 [==============================] - 3s 13ms/step - loss: 0.0128 - val_loss: 0.0143 - lr: 0.0100
# Epoch 267/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0129 - val_loss: 0.0128 - lr: 0.0100
# Epoch 268/300
# 188/188 [==============================] - 3s 13ms/step - loss: 0.0129 - val_loss: 0.0138 - lr: 0.0100
# Epoch 269/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0131 - val_loss: 0.0126 - lr: 0.0100
# Epoch 270/300
# 188/188 [==============================] - 3s 13ms/step - loss: 0.0128 - val_loss: 0.0129 - lr: 0.0100
# Epoch 271/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0129 - val_loss: 0.0140 - lr: 0.0100
# Epoch 272/300
# 188/188 [==============================] - 3s 13ms/step - loss: 0.0129 - val_loss: 0.0125 - lr: 0.0100
# Epoch 273/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0129 - val_loss: 0.0127 - lr: 0.0100
# Epoch 274/300
# 188/188 [==============================] - 3s 13ms/step - loss: 0.0130 - val_loss: 0.0128 - lr: 0.0100
# Epoch 275/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0130 - val_loss: 0.0129 - lr: 0.0100
# Epoch 276/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0131 - val_loss: 0.0124 - lr: 0.0100
# Epoch 277/300
# 188/188 [==============================] - 3s 13ms/step - loss: 0.0128 - val_loss: 0.0174 - lr: 0.0100
# Epoch 278/300
# 188/188 [==============================] - 3s 13ms/step - loss: 0.0134 - val_loss: 0.0157 - lr: 0.0100
# Epoch 279/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0130 - val_loss: 0.0137 - lr: 0.0100
# Epoch 280/300
# 188/188 [==============================] - 3s 13ms/step - loss: 0.0128 - val_loss: 0.0127 - lr: 0.0100
# Epoch 281/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0129 - val_loss: 0.0132 - lr: 0.0100
# Epoch 282/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0130 - val_loss: 0.0135 - lr: 0.0100
# Epoch 283/300
# 188/188 [==============================] - 3s 13ms/step - loss: 0.0130 - val_loss: 0.0134 - lr: 0.0100
# Epoch 284/300
# 188/188 [==============================] - 3s 13ms/step - loss: 0.0132 - val_loss: 0.0129 - lr: 0.0100
# Epoch 285/300
# 188/188 [==============================] - 3s 13ms/step - loss: 0.0129 - val_loss: 0.0129 - lr: 0.0100
# Epoch 286/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0128 - val_loss: 0.0125 - lr: 0.0100
# Epoch 287/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0129 - val_loss: 0.0124 - lr: 0.0100
# Epoch 288/300
# 188/188 [==============================] - 3s 13ms/step - loss: 0.0129 - val_loss: 0.0131 - lr: 0.0100
# Epoch 289/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0129 - val_loss: 0.0135 - lr: 0.0100
# Epoch 290/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0129 - val_loss: 0.0133 - lr: 0.0100
# Epoch 291/300
# 188/188 [==============================] - 3s 13ms/step - loss: 0.0130 - val_loss: 0.0131 - lr: 0.0100
# Epoch 292/300
# 188/188 [==============================] - 3s 13ms/step - loss: 0.0130 - val_loss: 0.0125 - lr: 0.0100
# Epoch 293/300
# 188/188 [==============================] - 3s 13ms/step - loss: 0.0127 - val_loss: 0.0136 - lr: 0.0100
# Epoch 294/300
# 188/188 [==============================] - 3s 13ms/step - loss: 0.0129 - val_loss: 0.0125 - lr: 0.0100
# Epoch 295/300
# 188/188 [==============================] - 3s 13ms/step - loss: 0.0128 - val_loss: 0.0133 - lr: 0.0100
# Epoch 296/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0130 - val_loss: 0.0137 - lr: 0.0100
# Epoch 297/300
# 188/188 [==============================] - 3s 13ms/step - loss: 0.0132 - val_loss: 0.0125 - lr: 0.0100
# Epoch 298/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0131 - val_loss: 0.0149 - lr: 0.0100
# Epoch 299/300
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0131 - val_loss: 0.0135 - lr: 0.0100
# Epoch 300/300
# 188/188 [==============================] - 3s 13ms/step - loss: 0.0128 - val_loss: 0.0128 - lr: 0.0100

# %%
from sklearn.metrics import mean_squared_error

# Reshape validation data (if required)
X_val_reshaped = X_val.reshape((X_val.shape[0], X_val.shape[1], 1))

# Predict
predictions = model.predict(X_val_reshaped)

# Calculate MSE
mse = mean_squared_error(y_val, predictions)
print(f"Mean Squared Error: {mse}")
# Out:
# 313/313 [==============================] - 1s 4ms/step
# Mean Squared Error: 0.01281500884567299

# %%
# Plotting
import matplotlib.pyplot as plt

plt.plot(history['loss'], label='Training Loss')
plt.plot(history['val_loss'], label='Validation Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Larger epoch training

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Dropout, Attention, LayerNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers.legacy import Adam
from tensorflow.keras.callbacks import EarlyStopping, TerminateOnNaN, LearningRateScheduler

num_predictions = 18

# Assuming final_training_data and final_validation_data are your datasets
# Reshape data for Transformer input
X_train = final_training_data[:, :-num_predictions]
y_train = final_training_data[:, -num_predictions:]

X_val = final_validation_data[:, :-num_predictions]
y_val = final_validation_data[:, -num_predictions:]

# Hyperparameters
d_model = 128  # Dimensionality of the model
num_heads = 64   # Number of attention heads
ff_dim = 128    # Dimensionality of the feed-forward layer

# Input layer
input_layer = Input(shape=(X_train.shape[1],))

# Transformer Encoder
x = Dense(d_model, activation='relu')(input_layer)
x = Dropout(0.1)(x)

x = Dense(ff_dim, activation='relu')(x)
x = Dropout(0.1)(x)

# Add layer normalization
x = LayerNormalization()(x)

# Output layer
output_layer = Dense(num_predictions)(x)

# Create and compile the model
model = Model(inputs=input_layer, outputs=output_layer)
optimizer = Adam(lr=0.001)  # Adjust the initial learning rate
model.compile(optimizer=optimizer, loss='mse')

# Callbacks
early_stopping = EarlyStopping(monitor='val_mse', patience=10, restore_best_weights=True)
terminate_on_nan = TerminateOnNaN()

# Learning rate scheduler
def lr_scheduler(epoch, lr):
    if epoch < 100:
        return lr
    else:
        return lr * tf.math.exp(-0.00002)

learning_rate_scheduler = LearningRateScheduler(lr_scheduler)

# Train the model
history = model.fit(
    X_train, 
    y_train, 
    validation_data=(X_val, y_val), 
    epochs=500, 
    batch_size=128,
    callbacks=[early_stopping, terminate_on_nan, learning_rate_scheduler]
).history
# Out:
# Epoch 1/1000
# 94/94 [==============================] - 2s 15ms/step - loss: 0.2865 - val_loss: 0.0347 - lr: 0.0010
# Epoch 2/1000
# 94/94 [==============================] - 1s 13ms/step - loss: 0.1093 - val_loss: 0.0291 - lr: 0.0010
# Epoch 3/1000
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0706 - val_loss: 0.0269 - lr: 0.0010
# Epoch 4/1000
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0517 - val_loss: 0.0259 - lr: 0.0010
# Epoch 5/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0428 - val_loss: 0.0243 - lr: 0.0010
# Epoch 6/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0376 - val_loss: 0.0236 - lr: 0.0010
# Epoch 7/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0345 - val_loss: 0.0227 - lr: 0.0010
# Epoch 8/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0324 - val_loss: 0.0226 - lr: 0.0010
# Epoch 9/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0305 - val_loss: 0.0221 - lr: 0.0010
# Epoch 10/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0289 - val_loss: 0.0207 - lr: 0.0010
# Epoch 11/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0276 - val_loss: 0.0202 - lr: 0.0010
# Epoch 12/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0263 - val_loss: 0.0201 - lr: 0.0010
# Epoch 13/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0251 - val_loss: 0.0195 - lr: 0.0010
# Epoch 14/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0242 - val_loss: 0.0193 - lr: 0.0010
# Epoch 15/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0236 - val_loss: 0.0189 - lr: 0.0010
# Epoch 16/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0225 - val_loss: 0.0187 - lr: 0.0010
# Epoch 17/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0219 - val_loss: 0.0187 - lr: 0.0010
# Epoch 18/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0216 - val_loss: 0.0179 - lr: 0.0010
# Epoch 19/1000
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0211 - val_loss: 0.0181 - lr: 0.0010
# Epoch 20/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0205 - val_loss: 0.0180 - lr: 0.0010
# Epoch 21/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0201 - val_loss: 0.0174 - lr: 0.0010
# Epoch 22/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0195 - val_loss: 0.0170 - lr: 0.0010
# Epoch 23/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0192 - val_loss: 0.0173 - lr: 0.0010
# Epoch 24/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0188 - val_loss: 0.0163 - lr: 0.0010
# Epoch 25/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0184 - val_loss: 0.0161 - lr: 0.0010
# Epoch 26/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0180 - val_loss: 0.0158 - lr: 0.0010
# Epoch 27/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0177 - val_loss: 0.0158 - lr: 0.0010
# Epoch 28/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0175 - val_loss: 0.0158 - lr: 0.0010
# Epoch 29/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0170 - val_loss: 0.0155 - lr: 0.0010
# Epoch 30/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0166 - val_loss: 0.0154 - lr: 0.0010
# Epoch 31/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0164 - val_loss: 0.0157 - lr: 0.0010
# Epoch 32/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0160 - val_loss: 0.0146 - lr: 0.0010
# Epoch 33/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0157 - val_loss: 0.0142 - lr: 0.0010
# Epoch 34/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0153 - val_loss: 0.0149 - lr: 0.0010
# Epoch 35/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0152 - val_loss: 0.0136 - lr: 0.0010
# Epoch 36/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0147 - val_loss: 0.0138 - lr: 0.0010
# Epoch 37/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0144 - val_loss: 0.0131 - lr: 0.0010
# Epoch 38/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0143 - val_loss: 0.0131 - lr: 0.0010
# Epoch 39/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0138 - val_loss: 0.0127 - lr: 0.0010
# Epoch 40/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0137 - val_loss: 0.0129 - lr: 0.0010
# Epoch 41/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0133 - val_loss: 0.0122 - lr: 0.0010
# Epoch 42/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0131 - val_loss: 0.0123 - lr: 0.0010
# Epoch 43/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0128 - val_loss: 0.0120 - lr: 0.0010
# Epoch 44/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0126 - val_loss: 0.0118 - lr: 0.0010
# Epoch 45/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0127 - val_loss: 0.0130 - lr: 0.0010
# Epoch 46/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0124 - val_loss: 0.0119 - lr: 0.0010
# Epoch 47/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0122 - val_loss: 0.0115 - lr: 0.0010
# Epoch 48/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0122 - val_loss: 0.0119 - lr: 0.0010
# Epoch 49/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0122 - val_loss: 0.0116 - lr: 0.0010
# Epoch 50/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0120 - val_loss: 0.0116 - lr: 0.0010
# Epoch 51/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0120 - val_loss: 0.0115 - lr: 0.0010
# Epoch 52/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0120 - val_loss: 0.0115 - lr: 0.0010
# Epoch 53/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0118 - val_loss: 0.0112 - lr: 0.0010
# Epoch 54/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0118 - val_loss: 0.0112 - lr: 0.0010
# Epoch 55/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0116 - val_loss: 0.0115 - lr: 0.0010
# Epoch 56/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0116 - val_loss: 0.0111 - lr: 0.0010
# Epoch 57/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0115 - val_loss: 0.0111 - lr: 0.0010
# Epoch 58/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0115 - val_loss: 0.0110 - lr: 0.0010
# Epoch 59/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0115 - val_loss: 0.0112 - lr: 0.0010
# Epoch 60/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0116 - val_loss: 0.0119 - lr: 0.0010
# Epoch 61/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0115 - val_loss: 0.0113 - lr: 0.0010
# Epoch 62/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0115 - val_loss: 0.0115 - lr: 0.0010
# Epoch 63/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0116 - val_loss: 0.0128 - lr: 0.0010
# Epoch 64/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0114 - val_loss: 0.0113 - lr: 0.0010
# Epoch 65/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0115 - val_loss: 0.0109 - lr: 0.0010
# Epoch 66/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0116 - val_loss: 0.0114 - lr: 0.0010
# Epoch 67/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0116 - val_loss: 0.0113 - lr: 0.0010
# Epoch 68/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0114 - val_loss: 0.0113 - lr: 0.0010
# Epoch 69/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0115 - val_loss: 0.0114 - lr: 0.0010
# Epoch 70/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0117 - val_loss: 0.0123 - lr: 0.0010
# Epoch 71/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0115 - val_loss: 0.0111 - lr: 0.0010
# Epoch 72/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0116 - val_loss: 0.0116 - lr: 0.0010
# Epoch 73/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0117 - val_loss: 0.0116 - lr: 0.0010
# Epoch 74/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0118 - val_loss: 0.0115 - lr: 0.0010
# Epoch 75/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0117 - val_loss: 0.0114 - lr: 0.0010
# Epoch 76/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0118 - val_loss: 0.0117 - lr: 0.0010
# Epoch 77/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0118 - val_loss: 0.0114 - lr: 0.0010
# Epoch 78/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0119 - val_loss: 0.0119 - lr: 0.0010
# Epoch 79/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0119 - val_loss: 0.0119 - lr: 0.0010
# Epoch 80/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0121 - val_loss: 0.0123 - lr: 0.0010
# Epoch 81/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0121 - val_loss: 0.0117 - lr: 0.0010
# Epoch 82/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0120 - val_loss: 0.0115 - lr: 0.0010
# Epoch 83/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0121 - val_loss: 0.0117 - lr: 0.0010
# Epoch 84/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0121 - val_loss: 0.0128 - lr: 0.0010
# Epoch 85/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0121 - val_loss: 0.0119 - lr: 0.0010
# Epoch 86/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0123 - val_loss: 0.0122 - lr: 0.0010
# Epoch 87/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0122 - val_loss: 0.0120 - lr: 0.0010
# Epoch 88/1000
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0124 - val_loss: 0.0118 - lr: 0.0010
# Epoch 89/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0123 - val_loss: 0.0123 - lr: 0.0010
# Epoch 90/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0123 - val_loss: 0.0123 - lr: 0.0010
# Epoch 91/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0123 - val_loss: 0.0120 - lr: 0.0010
# Epoch 92/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0124 - val_loss: 0.0120 - lr: 0.0010
# Epoch 93/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0124 - val_loss: 0.0123 - lr: 0.0010
# Epoch 94/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0126 - val_loss: 0.0121 - lr: 0.0010
# Epoch 95/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0127 - val_loss: 0.0125 - lr: 0.0010
# Epoch 96/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0127 - val_loss: 0.0125 - lr: 0.0010
# Epoch 97/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0127 - val_loss: 0.0123 - lr: 0.0010
# Epoch 98/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0127 - val_loss: 0.0124 - lr: 0.0010
# Epoch 99/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0128 - val_loss: 0.0124 - lr: 0.0010
# Epoch 100/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0128 - val_loss: 0.0123 - lr: 0.0010
# Epoch 101/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0128 - val_loss: 0.0127 - lr: 9.9998e-04
# Epoch 102/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0130 - val_loss: 0.0129 - lr: 9.9996e-04
# Epoch 103/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0129 - val_loss: 0.0126 - lr: 9.9994e-04
# Epoch 104/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0129 - val_loss: 0.0127 - lr: 9.9992e-04
# Epoch 105/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0130 - val_loss: 0.0126 - lr: 9.9990e-04
# Epoch 106/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0130 - val_loss: 0.0125 - lr: 9.9988e-04
# Epoch 107/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0131 - val_loss: 0.0126 - lr: 9.9986e-04
# Epoch 108/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0131 - val_loss: 0.0128 - lr: 9.9984e-04
# Epoch 109/1000
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0132 - val_loss: 0.0131 - lr: 9.9982e-04
# Epoch 110/1000
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0133 - val_loss: 0.0126 - lr: 9.9980e-04
# Epoch 111/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0131 - val_loss: 0.0129 - lr: 9.9978e-04
# Epoch 112/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0132 - val_loss: 0.0129 - lr: 9.9976e-04
# Epoch 113/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0132 - val_loss: 0.0128 - lr: 9.9974e-04
# Epoch 114/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0133 - val_loss: 0.0131 - lr: 9.9972e-04
# Epoch 115/1000
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0133 - val_loss: 0.0130 - lr: 9.9970e-04
# Epoch 116/1000
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0134 - val_loss: 0.0129 - lr: 9.9968e-04
# Epoch 117/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0134 - val_loss: 0.0138 - lr: 9.9966e-04
# Epoch 118/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0134 - val_loss: 0.0129 - lr: 9.9964e-04
# Epoch 119/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0136 - val_loss: 0.0130 - lr: 9.9962e-04
# Epoch 120/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0136 - val_loss: 0.0131 - lr: 9.9960e-04
# Epoch 121/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0136 - val_loss: 0.0136 - lr: 9.9958e-04
# Epoch 122/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0136 - val_loss: 0.0133 - lr: 9.9956e-04
# Epoch 123/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0135 - val_loss: 0.0131 - lr: 9.9954e-04
# Epoch 124/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0136 - val_loss: 0.0134 - lr: 9.9952e-04
# Epoch 125/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0136 - val_loss: 0.0132 - lr: 9.9950e-04
# Epoch 126/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0136 - val_loss: 0.0133 - lr: 9.9948e-04
# Epoch 127/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0136 - val_loss: 0.0144 - lr: 9.9946e-04
# Epoch 128/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0137 - val_loss: 0.0137 - lr: 9.9944e-04
# Epoch 129/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0137 - val_loss: 0.0138 - lr: 9.9942e-04
# Epoch 130/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0137 - val_loss: 0.0134 - lr: 9.9940e-04
# Epoch 131/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0138 - val_loss: 0.0132 - lr: 9.9938e-04
# Epoch 132/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0137 - val_loss: 0.0134 - lr: 9.9936e-04
# Epoch 133/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0137 - val_loss: 0.0134 - lr: 9.9934e-04
# Epoch 134/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0135 - lr: 9.9932e-04
# Epoch 135/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0139 - lr: 9.9930e-04
# Epoch 136/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0137 - val_loss: 0.0133 - lr: 9.9928e-04
# Epoch 137/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0133 - lr: 9.9926e-04
# Epoch 138/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0135 - lr: 9.9924e-04
# Epoch 139/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0138 - val_loss: 0.0134 - lr: 9.9922e-04
# Epoch 140/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0138 - val_loss: 0.0134 - lr: 9.9920e-04
# Epoch 141/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0134 - lr: 9.9918e-04
# Epoch 142/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0137 - lr: 9.9916e-04
# Epoch 143/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0136 - lr: 9.9914e-04
# Epoch 144/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0136 - lr: 9.9912e-04
# Epoch 145/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0140 - lr: 9.9910e-04
# Epoch 146/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0140 - lr: 9.9908e-04
# Epoch 147/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0139 - lr: 9.9906e-04
# Epoch 148/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0135 - lr: 9.9904e-04
# Epoch 149/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0136 - lr: 9.9902e-04
# Epoch 150/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0135 - lr: 9.9900e-04
# Epoch 151/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0137 - lr: 9.9898e-04
# Epoch 152/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0139 - lr: 9.9896e-04
# Epoch 153/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0141 - val_loss: 0.0142 - lr: 9.9894e-04
# Epoch 154/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0143 - lr: 9.9892e-04
# Epoch 155/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0139 - lr: 9.9890e-04
# Epoch 156/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0138 - lr: 9.9888e-04
# Epoch 157/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0143 - lr: 9.9886e-04
# Epoch 158/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0136 - lr: 9.9884e-04
# Epoch 159/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0134 - lr: 9.9882e-04
# Epoch 160/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0141 - val_loss: 0.0137 - lr: 9.9880e-04
# Epoch 161/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0138 - lr: 9.9878e-04
# Epoch 162/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0141 - val_loss: 0.0137 - lr: 9.9876e-04
# Epoch 163/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0139 - lr: 9.9874e-04
# Epoch 164/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0137 - lr: 9.9872e-04
# Epoch 165/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0140 - lr: 9.9870e-04
# Epoch 166/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0140 - lr: 9.9868e-04
# Epoch 167/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0136 - lr: 9.9866e-04
# Epoch 168/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0141 - val_loss: 0.0141 - lr: 9.9864e-04
# Epoch 169/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0137 - lr: 9.9862e-04
# Epoch 170/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0141 - lr: 9.9860e-04
# Epoch 171/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0141 - val_loss: 0.0145 - lr: 9.9858e-04
# Epoch 172/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0137 - lr: 9.9856e-04
# Epoch 173/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0139 - lr: 9.9854e-04
# Epoch 174/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0137 - lr: 9.9852e-04
# Epoch 175/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0137 - lr: 9.9850e-04
# Epoch 176/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0141 - val_loss: 0.0142 - lr: 9.9848e-04
# Epoch 177/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0139 - lr: 9.9846e-04
# Epoch 178/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0141 - lr: 9.9844e-04
# Epoch 179/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0141 - val_loss: 0.0138 - lr: 9.9842e-04
# Epoch 180/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0138 - lr: 9.9840e-04
# Epoch 181/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0141 - val_loss: 0.0143 - lr: 9.9838e-04
# Epoch 182/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0141 - val_loss: 0.0139 - lr: 9.9836e-04
# Epoch 183/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0142 - val_loss: 0.0145 - lr: 9.9834e-04
# Epoch 184/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0141 - val_loss: 0.0138 - lr: 9.9832e-04
# Epoch 185/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0141 - val_loss: 0.0141 - lr: 9.9830e-04
# Epoch 186/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0137 - lr: 9.9828e-04
# Epoch 187/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0141 - val_loss: 0.0140 - lr: 9.9826e-04
# Epoch 188/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0145 - lr: 9.9824e-04
# Epoch 189/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0137 - lr: 9.9822e-04
# Epoch 190/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0138 - lr: 9.9820e-04
# Epoch 191/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0139 - lr: 9.9818e-04
# Epoch 192/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0141 - val_loss: 0.0142 - lr: 9.9816e-04
# Epoch 193/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0141 - val_loss: 0.0141 - lr: 9.9814e-04
# Epoch 194/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0142 - val_loss: 0.0137 - lr: 9.9812e-04
# Epoch 195/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0140 - lr: 9.9810e-04
# Epoch 196/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0141 - val_loss: 0.0137 - lr: 9.9808e-04
# Epoch 197/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0138 - lr: 9.9806e-04
# Epoch 198/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0141 - val_loss: 0.0137 - lr: 9.9804e-04
# Epoch 199/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0141 - lr: 9.9802e-04
# Epoch 200/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0139 - lr: 9.9800e-04
# Epoch 201/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0141 - val_loss: 0.0137 - lr: 9.9798e-04
# Epoch 202/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0141 - val_loss: 0.0137 - lr: 9.9796e-04
# Epoch 203/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0138 - lr: 9.9794e-04
# Epoch 204/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0140 - lr: 9.9792e-04
# Epoch 205/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0141 - val_loss: 0.0143 - lr: 9.9790e-04
# Epoch 206/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0141 - val_loss: 0.0146 - lr: 9.9788e-04
# Epoch 207/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0141 - val_loss: 0.0137 - lr: 9.9786e-04
# Epoch 208/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0141 - val_loss: 0.0138 - lr: 9.9784e-04
# Epoch 209/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0141 - val_loss: 0.0141 - lr: 9.9782e-04
# Epoch 210/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0141 - val_loss: 0.0143 - lr: 9.9780e-04
# Epoch 211/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0141 - val_loss: 0.0140 - lr: 9.9778e-04
# Epoch 212/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0141 - val_loss: 0.0140 - lr: 9.9776e-04
# Epoch 213/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0137 - lr: 9.9774e-04
# Epoch 214/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0138 - lr: 9.9772e-04
# Epoch 215/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0141 - val_loss: 0.0144 - lr: 9.9770e-04
# Epoch 216/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0142 - lr: 9.9768e-04
# Epoch 217/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0138 - lr: 9.9766e-04
# Epoch 218/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0137 - lr: 9.9764e-04
# Epoch 219/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0136 - lr: 9.9762e-04
# Epoch 220/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0141 - val_loss: 0.0139 - lr: 9.9760e-04
# Epoch 221/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0137 - lr: 9.9758e-04
# Epoch 222/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0137 - lr: 9.9756e-04
# Epoch 223/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0141 - val_loss: 0.0141 - lr: 9.9754e-04
# Epoch 224/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0140 - lr: 9.9752e-04
# Epoch 225/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0138 - lr: 9.9750e-04
# Epoch 226/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0137 - lr: 9.9748e-04
# Epoch 227/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0139 - lr: 9.9746e-04
# Epoch 228/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0149 - lr: 9.9744e-04
# Epoch 229/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0141 - val_loss: 0.0139 - lr: 9.9742e-04
# Epoch 230/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0137 - lr: 9.9740e-04
# Epoch 231/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0141 - val_loss: 0.0137 - lr: 9.9738e-04
# Epoch 232/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0141 - val_loss: 0.0143 - lr: 9.9736e-04
# Epoch 233/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0143 - lr: 9.9734e-04
# Epoch 234/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0145 - lr: 9.9732e-04
# Epoch 235/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0141 - val_loss: 0.0141 - lr: 9.9730e-04
# Epoch 236/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0139 - lr: 9.9728e-04
# Epoch 237/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0138 - lr: 9.9726e-04
# Epoch 238/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0140 - lr: 9.9724e-04
# Epoch 239/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0138 - lr: 9.9722e-04
# Epoch 240/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0138 - lr: 9.9720e-04
# Epoch 241/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0137 - lr: 9.9718e-04
# Epoch 242/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0147 - lr: 9.9716e-04
# Epoch 243/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0136 - lr: 9.9714e-04
# Epoch 244/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0137 - lr: 9.9712e-04
# Epoch 245/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0139 - lr: 9.9710e-04
# Epoch 246/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0138 - lr: 9.9708e-04
# Epoch 247/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0136 - lr: 9.9706e-04
# Epoch 248/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0144 - lr: 9.9704e-04
# Epoch 249/1000
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0140 - val_loss: 0.0138 - lr: 9.9702e-04
# Epoch 250/1000
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0139 - val_loss: 0.0137 - lr: 9.9700e-04
# Epoch 251/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0137 - lr: 9.9697e-04
# Epoch 252/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0139 - lr: 9.9695e-04
# Epoch 253/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0138 - lr: 9.9693e-04
# Epoch 254/1000
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0139 - val_loss: 0.0136 - lr: 9.9691e-04
# Epoch 255/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0137 - lr: 9.9689e-04
# Epoch 256/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0139 - lr: 9.9687e-04
# Epoch 257/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0138 - lr: 9.9685e-04
# Epoch 258/1000
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0139 - val_loss: 0.0137 - lr: 9.9683e-04
# Epoch 259/1000
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0139 - val_loss: 0.0137 - lr: 9.9681e-04
# Epoch 260/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0138 - val_loss: 0.0138 - lr: 9.9679e-04
# Epoch 261/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0139 - lr: 9.9677e-04
# Epoch 262/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0138 - val_loss: 0.0136 - lr: 9.9675e-04
# Epoch 263/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0138 - val_loss: 0.0135 - lr: 9.9673e-04
# Epoch 264/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0140 - val_loss: 0.0139 - lr: 9.9671e-04
# Epoch 265/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0138 - val_loss: 0.0137 - lr: 9.9669e-04
# Epoch 266/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0138 - val_loss: 0.0137 - lr: 9.9667e-04
# Epoch 267/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0137 - val_loss: 0.0138 - lr: 9.9665e-04
# Epoch 268/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0138 - val_loss: 0.0135 - lr: 9.9663e-04
# Epoch 269/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0138 - lr: 9.9661e-04
# Epoch 270/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0138 - val_loss: 0.0135 - lr: 9.9659e-04
# Epoch 271/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0137 - val_loss: 0.0135 - lr: 9.9657e-04
# Epoch 272/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0134 - lr: 9.9655e-04
# Epoch 273/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0134 - lr: 9.9653e-04
# Epoch 274/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0138 - val_loss: 0.0137 - lr: 9.9651e-04
# Epoch 275/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0134 - lr: 9.9649e-04
# Epoch 276/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0138 - val_loss: 0.0136 - lr: 9.9647e-04
# Epoch 277/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0138 - val_loss: 0.0140 - lr: 9.9645e-04
# Epoch 278/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0137 - val_loss: 0.0137 - lr: 9.9643e-04
# Epoch 279/1000
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0137 - val_loss: 0.0135 - lr: 9.9641e-04
# Epoch 280/1000
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0138 - val_loss: 0.0134 - lr: 9.9639e-04
# Epoch 281/1000
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0138 - val_loss: 0.0135 - lr: 9.9637e-04
# Epoch 282/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0137 - val_loss: 0.0135 - lr: 9.9635e-04
# Epoch 283/1000
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0137 - val_loss: 0.0138 - lr: 9.9633e-04
# Epoch 284/1000
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0137 - val_loss: 0.0136 - lr: 9.9631e-04
# Epoch 285/1000
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0137 - val_loss: 0.0136 - lr: 9.9629e-04
# Epoch 286/1000
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0137 - val_loss: 0.0135 - lr: 9.9627e-04
# Epoch 287/1000
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0137 - val_loss: 0.0138 - lr: 9.9625e-04
# Epoch 288/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0137 - val_loss: 0.0145 - lr: 9.9623e-04
# Epoch 289/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0137 - val_loss: 0.0136 - lr: 9.9621e-04
# Epoch 290/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0136 - val_loss: 0.0135 - lr: 9.9619e-04
# Epoch 291/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0136 - val_loss: 0.0133 - lr: 9.9617e-04
# Epoch 292/1000
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0136 - val_loss: 0.0132 - lr: 9.9615e-04
# Epoch 293/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0136 - val_loss: 0.0132 - lr: 9.9613e-04
# Epoch 294/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0136 - val_loss: 0.0139 - lr: 9.9611e-04
# Epoch 295/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0136 - val_loss: 0.0134 - lr: 9.9609e-04
# Epoch 296/1000
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0136 - val_loss: 0.0134 - lr: 9.9607e-04
# Epoch 297/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0135 - val_loss: 0.0134 - lr: 9.9605e-04
# Epoch 298/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0134 - val_loss: 0.0131 - lr: 9.9603e-04
# Epoch 299/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0136 - val_loss: 0.0134 - lr: 9.9601e-04
# Epoch 300/1000
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0134 - val_loss: 0.0134 - lr: 9.9599e-04
# Epoch 301/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0134 - val_loss: 0.0135 - lr: 9.9597e-04
# Epoch 302/1000
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0135 - val_loss: 0.0132 - lr: 9.9595e-04
# Epoch 303/1000
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0135 - val_loss: 0.0134 - lr: 9.9593e-04
# Epoch 304/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0135 - val_loss: 0.0136 - lr: 9.9591e-04
# Epoch 305/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0133 - val_loss: 0.0135 - lr: 9.9589e-04
# Epoch 306/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0134 - val_loss: 0.0130 - lr: 9.9587e-04
# Epoch 307/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0134 - val_loss: 0.0133 - lr: 9.9585e-04
# Epoch 308/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0134 - val_loss: 0.0131 - lr: 9.9583e-04
# Epoch 309/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0134 - val_loss: 0.0135 - lr: 9.9581e-04
# Epoch 310/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0133 - val_loss: 0.0136 - lr: 9.9579e-04
# Epoch 311/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0135 - val_loss: 0.0132 - lr: 9.9577e-04
# Epoch 312/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0134 - val_loss: 0.0133 - lr: 9.9575e-04
# Epoch 313/1000
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0133 - val_loss: 0.0134 - lr: 9.9573e-04
# Epoch 314/1000
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0133 - val_loss: 0.0136 - lr: 9.9571e-04
# Epoch 315/1000
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0134 - val_loss: 0.0131 - lr: 9.9569e-04
# Epoch 316/1000
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0133 - val_loss: 0.0134 - lr: 9.9567e-04
# Epoch 317/1000
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0133 - val_loss: 0.0131 - lr: 9.9565e-04
# Epoch 318/1000
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0134 - val_loss: 0.0132 - lr: 9.9563e-04
# Epoch 319/1000
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0133 - val_loss: 0.0134 - lr: 9.9561e-04
# Epoch 320/1000
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0133 - val_loss: 0.0130 - lr: 9.9559e-04
# Epoch 321/1000
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0134 - val_loss: 0.0135 - lr: 9.9557e-04
# Epoch 322/1000
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0133 - val_loss: 0.0132 - lr: 9.9555e-04
# Epoch 323/1000
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0133 - val_loss: 0.0133 - lr: 9.9553e-04
# Epoch 324/1000
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0132 - val_loss: 0.0132 - lr: 9.9551e-04
# Epoch 325/1000
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0132 - val_loss: 0.0133 - lr: 9.9549e-04
# Epoch 326/1000
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0133 - val_loss: 0.0131 - lr: 9.9547e-04
# Epoch 327/1000
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0133 - val_loss: 0.0131 - lr: 9.9545e-04
# Epoch 328/1000
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0132 - val_loss: 0.0136 - lr: 9.9543e-04
# Epoch 329/1000
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0133 - val_loss: 0.0135 - lr: 9.9541e-04
# Epoch 330/1000
# 93/94 [============================>.] - ETA: 0s - loss: 0.0133

# %%
from sklearn.metrics import mean_squared_error

# Reshape validation data (if required)
X_val_reshaped = X_val.reshape((X_val.shape[0], X_val.shape[1], 1))

# Predict
predictions = model.predict(X_val_reshaped)

# Calculate MSE
mse = mean_squared_error(y_val, predictions)
print(f"Mean Squared Error: {mse}")
# Out:
# 313/313 [==============================] - 1s 4ms/step
# Mean Squared Error: 0.012576692625989198

# %%
# Plotting
import matplotlib.pyplot as plt

plt.plot(history['loss'], label='Training Loss')
plt.plot(history['val_loss'], label='Validation Loss')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 4
#       1 # Plotting
#       2 import matplotlib.pyplot as plt
# ----> 4 plt.plot(history['loss'], label='Training Loss')
#       5 plt.plot(history['val_loss'], label='Validation Loss')
#       6 plt.legend()
#
# NameError: name 'history' is not defined

# %%
save_model(model, f'{mse}')

# %%
from datetime import datetime

def save_model(model, description):
    current_datetime = datetime.now()
    formatted_datetime = current_datetime.strftime("%d%m_%H%M")

    model.save('models/' + formatted_datetime + '_' + description + '.h5')
